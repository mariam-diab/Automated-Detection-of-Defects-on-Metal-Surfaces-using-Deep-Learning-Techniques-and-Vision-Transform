# %%
import pydot, graphviz
import tensorflow as tf
from keras import regularizers
from keras.models import Sequential, load_model
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten, Dropout, concatenate, GlobalAveragePooling2D, Reshape
from keras.utils import np_utils
from tensorflow.keras.utils import plot_model
from keras.models import Model
from tensorflow.keras.applications import ResNet50
import cv2
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
from sklearn.model_selection import train_test_split
import os
import pandas as pd
import xml.etree.ElementTree as ET
from sklearn.preprocessing import MinMaxScaler
from PIL import Image
from tensorflow.keras.applications.inception_v3 import InceptionV3
from keras import Model

# %%
mapping = {
    "1_chongkong" : 0,
    "2_hanfeng" : 1,
    "3_yueyawan": 2,
    "4_shuiban": 3,
    "5_youban": 4,
    "6_siban": 5,
    "7_yiwu": 6,
    "8_yahen": 11,
    "9_zhehen": 7,
    "10_yaozhed": 8,
    "scratches": 9,
    "rolled-in_scale": 10
}
mapping2 = {
    0 : "Punching Hole",
    1 : "Welding Line",
    2 : "Crescent Gap",
    3 : "Water Spot",
    4 : "Oil Spot",
    5 : "Silk Spot",
    6 : "Inclusion",
    11 : "Rolled Pit",
    7 : "Crease",
    8 : "Waist Folding",
    9 : "Scratches",
    10 : "Rolled in Scale"
}

# %%
X = []
y = []
X_train = []
y_train = []
X_val = []
y_val = []
w = int(2048/8)
l = int(1000/4)

# %%
def get_annotations(directory):
    try:
        tree = ET.parse(directory)
        root = tree.getroot()
        boxes = []

        defect = -1
        objs = root.findall('object')
        for i in objs:
            name = i.find('name').text
            defect = mapping.get(name, 12)
            if defect != 12 and defect != 11:
                box = i.find('bndbox')
                xmin = float(box.find('xmin').text)
                ymin = float(box.find('ymin').text)
                xmax = float(box.find('xmax').text)
                ymax = float(box.find('ymax').text)
                
                if defect == -1:
                    return 0
                if xmin > xmax:
                    temp = xmin
                    xmin = xmax
                    xmax = temp
                if ymin > ymax:
                    temp = ymin
                    ymin = ymax
                    ymax = temp
                    
                box = []
                for i in range(5):
                    box.append(-1)
                box[0] = defect
                box[1] = (xmin)/8.0
                box[2] = (ymin)/4.0
                box[3] = (xmax)/8.0
                box[4] = (ymax)/4.0
                boxes.append(box)
            else:
                defect = -1
        if defect == -1:
            return 0
        return boxes
    except:
        return 0

# %%
cd "C:\\Users\\Toqa Alaa\\PBL2"
# Out:
# C:\Users\Toqa Alaa\PBL2

# %%
#Displaying sample data for all classes
path ='gc10det/crease'
for img in os.listdir(path):
    img_array1 = cv2.imread(os.path.join(path,img))
    img_array1 = cv2.resize(img_array1, (100, 100))
    break

path ='gc10det/crescent_gap'
for img in os.listdir(path):
    img_array2 = cv2.imread(os.path.join(path,img))
    img_array2 = cv2.resize(img_array2, (100, 100))
    break
    
    
path ='gc10det/inclusion'
for img in os.listdir(path):
    img_array3 = cv2.imread(os.path.join(path,img))
    img_array3 = cv2.resize(img_array3, (100, 100))
    break
    
    
path ='gc10det/oil_spot'
for img in os.listdir(path):
    img_array4 = cv2.imread(os.path.join(path,img))
    img_array4 = cv2.resize(img_array4, (100, 100))
    break
    
path ='gc10det/punching_hole'
for img in os.listdir(path):
    img_array5 = cv2.imread(os.path.join(path,img))
    img_array5 = cv2.resize(img_array5, (100, 100))
    break
    
path ='gc10det/rolled_in_scale'
for img in os.listdir(path):
    img_array6 = cv2.imread(os.path.join(path,img))
    img_array6 = cv2.resize(img_array6, (100, 100))
    break

path ='gc10det/scratches'
for img in os.listdir(path):
    img_array7 = cv2.imread(os.path.join(path,img))
    img_array7 = cv2.resize(img_array7, (100, 100))
    break
    
    
path ='gc10det/silk_spot'
for img in os.listdir(path):
    img_array8 = cv2.imread(os.path.join(path,img))
    img_array8 = cv2.resize(img_array8, (100, 100))
    break
    
    
path ='gc10det/waist_folding'
for img in os.listdir(path):
    img_array9 = cv2.imread(os.path.join(path,img))
    img_array9 = cv2.resize(img_array9, (100, 100))
    break
    
path ='gc10det/water_spot'
for img in os.listdir(path):
    img_array10 = cv2.imread(os.path.join(path,img))
    img_array10 = cv2.resize(img_array10, (100, 100))
    break
    
path ='gc10det/welding_line'
for img in os.listdir(path):
    img_array11 = cv2.imread(os.path.join(path,img))
    img_array11 = cv2.resize(img_array11, (100, 100))
    break
    
fig = plt.figure(figsize=(15, 15))
spec = gridspec.GridSpec(ncols=3, nrows=4,
                         width_ratios=[1, 1, 1], wspace=0.4,
                         hspace=0.4, height_ratios=[1, 1, 1, 1])
ax1 = fig.add_subplot(3, 4, 1)
ax1.imshow(img_array1, cmap='gray')
fig.suptitle("Sample images for 11 classes")
ax1.set_title("Crease")
ax2 = fig.add_subplot(3, 4, 2)
ax2.imshow(img_array2, cmap='gray')
ax2.set_title("Crescent Gap")
ax3 = fig.add_subplot(3, 4, 3)
ax3.imshow(img_array3, cmap='gray')
ax3.set_title("Inclusion")
ax4 = fig.add_subplot(3, 4, 4)
ax4.imshow(img_array4, cmap='gray')
ax4.set_title("Oil Spot")
ax5 = fig.add_subplot(3, 4, 5)
ax5.imshow(img_array5, cmap='gray')
ax5.set_title("Punching Hole")
ax6 = fig.add_subplot(3, 4, 6)
ax6.imshow(img_array6, cmap='gray')
ax6.set_title("Rolled in Scale")
ax7 = fig.add_subplot(3, 4, 7)
ax7.imshow(img_array7, cmap='gray')
ax7.set_title("Scratches")
ax8 = fig.add_subplot(3, 4, 8)
ax8.imshow(img_array8, cmap='gray')
ax8.set_title("Silk Spot")
ax9 = fig.add_subplot(3, 4, 9)
ax9.imshow(img_array9, cmap='gray')
ax9.set_title("Waist Folding")
ax10 = fig.add_subplot(3, 4, 10)
ax10.imshow(img_array10, cmap='gray')
ax10.set_title("Water Spot")
ax11 = fig.add_subplot(3, 4, 11)
ax11.imshow(img_array11, cmap='gray')
ax11.set_title("Welding Line")
# Out:
# Text(0.5, 1.0, 'Welding Line')

# %%
for i in range(1, 54):
    annotation = get_annotations(fr'lable/crease ({i}).xml')
    if(annotation):
        img = cv2.imread(fr'gc10det/crease/crease ({i}).jpg')
        img = cv2.resize(img, (w, l))
        X.append(img)
        y.append(annotation)

for i in range(1, 227):
    annotation = get_annotations(fr'lable/crescent_gap ({i}).xml')
    if(annotation):
        img = cv2.imread(fr'gc10det/crescent_gap/crescent_gap ({i}).jpg')
        img = cv2.resize(img, (w, l))
        X.append(img)
        y.append(annotation)
    
for i in range(1, 493):
    annotation = get_annotations(fr'lable/inclusion ({i}).xml')
    if(annotation):
        img = cv2.imread(fr'gc10det/inclusion/inclusion ({i}).jpg')
        img = cv2.resize(img, (w, l))
        X.append(img)
        y.append(annotation)

for i in range(1, 205):
    annotation = get_annotations(fr'lable/oil_spot ({i}).xml')
    if(annotation):
        img = cv2.imread(fr'gc10det/oil_spot/oil_spot ({i}).jpg')
        img = cv2.resize(img, (w, l))
        X.append(img)
        y.append(annotation)

for i in range(1, 220):
    annotation = get_annotations(fr'lable/punching_hole ({i}).xml')
    if(annotation):
        img = cv2.imread(fr'gc10det/punching_hole/punching_hole ({i}).jpg')
        img = cv2.resize(img, (w, l))
        X.append(img)
        y.append(annotation)

for i in range(1, 277):
    annotation = get_annotations(fr'lable/rolled_in_scale ({i}).xml')
    if(annotation):
        img = cv2.imread(fr'gc10det/rolled_in_scale/rolled_in_scale ({i}).jpg')
        img = cv2.resize(img, (w, l))
        X.append(img)
        y.append(annotation)
    
for i in range(1, 277):
    annotation = get_annotations(fr'lable/scratches ({i}).xml')
    if(annotation):
        img = cv2.imread(fr'gc10det/scratches/scratches ({i}).jpg')
        img = cv2.resize(img, (w, l))
        X.append(img)
        y.append(annotation)
    
for i in range(1, 652):
    annotation = get_annotations(fr'lable/silk_spot ({i}).xml')
    if(annotation):
        img = cv2.imread(fr'gc10det/silk_spot/silk_spot ({i}).jpg')
        img = cv2.resize(img, (w, l))
        X.append(img)
        y.append(annotation)

for i in range(1, 150):
    annotation = get_annotations(fr'lable/waist_folding ({i}).xml')
    if(annotation):
        img = cv2.imread(fr'gc10det/waist_folding/waist_folding ({i}).jpg')
        img = cv2.resize(img, (w, l))
        X.append(img)
        y.append(annotation)
    
for i in range(1, 290):
    annotation = get_annotations(fr'lable/water_spot ({i}).xml')
    if(annotation):
        img = cv2.imread(fr'gc10det/water_spot/water_spot ({i}).jpg')
        img = cv2.resize(img, (w, l))
        X.append(img)
        y.append(annotation)

for i in range(1, 274):
    annotation = get_annotations(fr'lable/welding_line ({i}).xml')
    if(annotation):
        img = cv2.imread(fr'gc10det/welding_line/welding_line ({i}).jpg')
        img = cv2.resize(img, (w, l))
        X.append(img)
        y.append(annotation)

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
classes_train = []
dims_train = []
for i in range(len(y_train)):
    tmp_classes = []
    tmp_dims = []
    for j in range(len(y_train[i])):
        tmp_classes.append(y_train[i][j][0])
        tmp_dims.append(y_train[i][j][1:])
    classes_train.append(tmp_classes)
    dims_train.append(tmp_dims)

classes_val = []
dims_val = []
for i in range(len(y_val)):
    tmp_classes = []
    tmp_dims = []
    for j in range(len(y_val[i])):
        tmp_classes.append(y_val[i][j][0])
        tmp_dims.append(y_val[i][j][1:])
    classes_val.append(tmp_classes)
    dims_val.append(tmp_dims)

# %%
X_train = np.array(X_train, dtype = 'float')
#X_test = np.array(X_test, dtype = 'float')
X_val = np.array(X_val, dtype = 'float')

X_train /= 255.0
#X_test /= 255
X_val/= 255.0

# %%
def extract_min(lst, index):
    minn = 10000000
    for i in range(len(lst)):
        for j in range(len(lst[i])):
            if lst[i][j][index] < minn:
                minn = lst[i][j][index]
    return minn

def extract_max(lst, index):
    maxx = -10000000
    for i in range(len(lst)):
        for j in range(len(lst[i])):
            if lst[i][j][index] > maxx:
                maxx = lst[i][j][index]
    return maxx

# %%
def maxminscaler(lst, maxx, minn, index):
    for i in range(len(lst)):
        for j in range(len(lst[i])):
            lst[i][j][index] = (lst[i][j][index] - minn)/(maxx - minn)
    return lst

# %%
xmin_min = extract_min(dims_train, 0)
xmin_max = extract_max(dims_train, 0)
xmax_min = extract_min(dims_train, 1)
xmax_max = extract_max(dims_train, 1)
ymin_min = extract_min(dims_train, 2)
ymin_max = extract_max(dims_train, 2)
ymax_min = extract_min(dims_train, 3)
ymax_max = extract_max(dims_train, 3)

# %%
dims_train = maxminscaler(dims_train, xmin_min, xmin_max, 0)
dims_train = maxminscaler(dims_train, xmax_min, xmax_max, 1)
dims_train = maxminscaler(dims_train, ymin_min, ymin_max, 2)
dims_train = maxminscaler(dims_train, ymax_min, ymax_max, 3)

dims_val = maxminscaler(dims_val, xmin_min, xmin_max, 0)
dims_val = maxminscaler(dims_val, xmax_min, xmax_max, 1)
dims_val = maxminscaler(dims_val, ymin_min, ymin_max, 2)
dims_val = maxminscaler(dims_val, ymax_min, ymax_max, 3)

# %%
maximum_defects = 0
for i in dims_val:
    if len(i) > maximum_defects:
        maximum_defects = len(i)
        
print(maximum_defects)
# Out:
# 11

# %%
def pad_dims(lst):
    pad = [-1, -1, -1, -1]
    for i in range(len(lst)):
        for _ in range(11 - len(lst[i])):
            lst[i].append(pad)
    return lst

def pad_classes(lst):
    pad = -1
    for i in range(len(lst)):
        for _ in range(11 - len(lst[i])):
            lst[i].append(pad)
    return lst

# %%
dims_train = pad_dims(dims_train)
dims_val = pad_dims(dims_val)
classes_train = pad_classes(classes_train)
classes_val = pad_classes(classes_val)

# %%
num_classes = 12

for i in range(len(classes_train)):
    classes_train[i] = np.array(classes_train[i], dtype = 'float').astype('float64').reshape((-1,1))
    classes_train[i] = np_utils.to_categorical(classes_train[i], num_classes=num_classes)

for i in range(len(dims_train)):
    dims_train[i] = np.array(dims_train[i], dtype = 'float')

for i in range(len(classes_val)):
    classes_val[i] = np.array(classes_val[i], dtype = 'float').astype('float64').reshape((-1,1))
    classes_val[i] = np_utils.to_categorical(classes_val[i], num_classes=num_classes)

for i in range(len(dims_val)):
    dims_val[i] = np.array(dims_val[i], dtype = 'float')

num_regressors = 4

# %%
for i in range(len(dims_val)):
    if (len(dims_val[i])!=11):
        print(i)
    #print(len(i))
#dims_val[288]

# %%
print(len(dims_train[0]))
dims_train = np.array(dims_train, dtype = 'float')
dims_val = np.array(dims_val, dtype = 'float')
classes_train = np.array(classes_train, dtype = 'float')
classes_val = np.array(classes_val, dtype = 'float')
# Out:
# 11

# %%
pre_trained_model = InceptionV3(include_top = False, 
                                weights = 'imagenet')

for layer in pre_trained_model.layers[:-10]:
    layer.trainable = False
for layer in pre_trained_model.layers[-10:]:
    layer.trainable = True

# %%
input_shape = (l, w, 3)

inputs = Input(shape=input_shape)

l1 = pre_trained_model(inputs)

flatten = GlobalAveragePooling2D()(l1)

dense_class1 = Dense(128, activation='relu')(flatten)
dense_class2 = Dense(64, activation='relu')(dense_class1)
output_class = Dense(11*12, activation='softmax')(dense_class2)
output_class = Reshape((11, 12), name='class_output')(output_class)

dense_reg1 = Dense(1024, activation='relu')(flatten)
dropout1 = Dropout(0.2)(dense_reg1)
dense_reg2 = Dense(1024, activation='relu')(dropout1)
dropout2 = Dropout(0.2)(dense_reg2)
output_reg = Dense(11*4)(dropout2)
output_reg = Reshape((11, 4), name='reg_output')(output_reg)

#combined_output = concatenate([output_class, output_reg])

model = Model(inputs=inputs, outputs=[output_class, output_reg])

model.compile(optimizer='adam',
              loss={'class_output': 'categorical_crossentropy',
                    'reg_output': 'mse'},
              loss_weights={'class_output': 0.1, 'reg_output': 1.0},
              metrics={'class_output': 'accuracy',
                       'reg_output': 'mae'})

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 250, 256, 3  0           []
#                                 )]
#
#  inception_v3 (Functional)      (None, None, None,   21802784    ['input_2[0][0]']
#                                 2048)
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['inception_v3[0][0]']
#  alAveragePooling2D)
#
#  dense_3 (Dense)                (None, 1024)         2098176     ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dropout (Dropout)              (None, 1024)         0           ['dense_3[0][0]']
#
#  dense (Dense)                  (None, 128)          262272      ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_4 (Dense)                (None, 1024)         1049600     ['dropout[0][0]']
#
#  dense_1 (Dense)                (None, 64)           8256        ['dense[0][0]']
#
#  dropout_1 (Dropout)            (None, 1024)         0           ['dense_4[0][0]']
#
#  dense_2 (Dense)                (None, 132)          8580        ['dense_1[0][0]']
#
#  dense_5 (Dense)                (None, 44)           45100       ['dropout_1[0][0]']
#
#  class_output (Reshape)         (None, 11, 12)       0           ['dense_2[0][0]']
#
#  reg_output (Reshape)           (None, 11, 4)        0           ['dense_5[0][0]']
#
# ==================================================================================================
# Total params: 25,274,768
# Trainable params: 3,472,176
# Non-trainable params: 21,802,592
# __________________________________________________________________________________________________

# %%
plot_model(model, to_file='model_diagram.png', show_shapes=True)

# %%
H = model.fit(X_train, {'class_output': classes_train, 'reg_output': dims_train},
                    validation_data=(X_val, {'class_output': classes_val, 'reg_output': dims_val}),
                    batch_size=8, epochs=60)
model.save("annotations_multi.h5")
# Out:
# Epoch 1/60
# 230/230 [==============================] - 73s 318ms/step - loss: 0.0374 - class_output_loss: 0.0023 - reg_output_loss: 0.0372 - class_output_accuracy: 0.9996 - reg_output_mae: 0.0792 - val_loss: 0.1294 - val_class_output_loss: 0.4560 - val_reg_output_loss: 0.0838 - val_class_output_accuracy: 0.9402 - val_reg_output_mae: 0.0962
# Epoch 2/60
# 230/230 [==============================] - 72s 313ms/step - loss: 0.0383 - class_output_loss: 0.0012 - reg_output_loss: 0.0382 - class_output_accuracy: 0.9999 - reg_output_mae: 0.0789 - val_loss: 0.1286 - val_class_output_loss: 0.4531 - val_reg_output_loss: 0.0833 - val_class_output_accuracy: 0.9421 - val_reg_output_mae: 0.1033
# Epoch 3/60
# 230/230 [==============================] - 73s 316ms/step - loss: 0.0389 - class_output_loss: 6.1981e-04 - reg_output_loss: 0.0388 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0810 - val_loss: 0.1306 - val_class_output_loss: 0.4626 - val_reg_output_loss: 0.0843 - val_class_output_accuracy: 0.9420 - val_reg_output_mae: 0.1005
# Epoch 4/60
# 230/230 [==============================] - 73s 318ms/step - loss: 0.0387 - class_output_loss: 4.8265e-04 - reg_output_loss: 0.0386 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0794 - val_loss: 0.1301 - val_class_output_loss: 0.4676 - val_reg_output_loss: 0.0834 - val_class_output_accuracy: 0.9423 - val_reg_output_mae: 0.1074
# Epoch 5/60
# 230/230 [==============================] - 73s 318ms/step - loss: 0.0387 - class_output_loss: 4.2391e-04 - reg_output_loss: 0.0387 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0811 - val_loss: 0.1289 - val_class_output_loss: 0.4717 - val_reg_output_loss: 0.0818 - val_class_output_accuracy: 0.9427 - val_reg_output_mae: 0.1002
# Epoch 6/60
# 230/230 [==============================] - 73s 316ms/step - loss: 0.0368 - class_output_loss: 3.8496e-04 - reg_output_loss: 0.0368 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0771 - val_loss: 0.1267 - val_class_output_loss: 0.4801 - val_reg_output_loss: 0.0786 - val_class_output_accuracy: 0.9420 - val_reg_output_mae: 0.1015
# Epoch 7/60
# 230/230 [==============================] - 71s 308ms/step - loss: 0.0352 - class_output_loss: 2.9435e-04 - reg_output_loss: 0.0352 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0758 - val_loss: 0.1300 - val_class_output_loss: 0.4890 - val_reg_output_loss: 0.0811 - val_class_output_accuracy: 0.9416 - val_reg_output_mae: 0.1011
# Epoch 8/60
# 230/230 [==============================] - 71s 308ms/step - loss: 0.0344 - class_output_loss: 2.9806e-04 - reg_output_loss: 0.0343 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0745 - val_loss: 0.1341 - val_class_output_loss: 0.4834 - val_reg_output_loss: 0.0858 - val_class_output_accuracy: 0.9424 - val_reg_output_mae: 0.1022
# Epoch 9/60
# 230/230 [==============================] - 71s 311ms/step - loss: 0.0384 - class_output_loss: 2.1412e-04 - reg_output_loss: 0.0384 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0789 - val_loss: 0.1298 - val_class_output_loss: 0.4887 - val_reg_output_loss: 0.0810 - val_class_output_accuracy: 0.9423 - val_reg_output_mae: 0.1022
# Epoch 10/60
# 230/230 [==============================] - 71s 310ms/step - loss: 0.0365 - class_output_loss: 2.0431e-04 - reg_output_loss: 0.0365 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0774 - val_loss: 0.1314 - val_class_output_loss: 0.4948 - val_reg_output_loss: 0.0819 - val_class_output_accuracy: 0.9420 - val_reg_output_mae: 0.1004
# Epoch 11/60
# 230/230 [==============================] - 71s 308ms/step - loss: 0.0389 - class_output_loss: 1.6815e-04 - reg_output_loss: 0.0389 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0796 - val_loss: 0.1351 - val_class_output_loss: 0.4970 - val_reg_output_loss: 0.0854 - val_class_output_accuracy: 0.9431 - val_reg_output_mae: 0.1000
# Epoch 12/60
# 230/230 [==============================] - 72s 312ms/step - loss: 0.0390 - class_output_loss: 1.4260e-04 - reg_output_loss: 0.0390 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0784 - val_loss: 0.1343 - val_class_output_loss: 0.5010 - val_reg_output_loss: 0.0842 - val_class_output_accuracy: 0.9422 - val_reg_output_mae: 0.1050
# Epoch 13/60
# 230/230 [==============================] - 71s 309ms/step - loss: 0.0360 - class_output_loss: 1.3398e-04 - reg_output_loss: 0.0360 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0772 - val_loss: 0.1315 - val_class_output_loss: 0.4994 - val_reg_output_loss: 0.0815 - val_class_output_accuracy: 0.9415 - val_reg_output_mae: 0.0964
# Epoch 14/60
# 230/230 [==============================] - 72s 315ms/step - loss: 0.0435 - class_output_loss: 0.0496 - reg_output_loss: 0.0385 - class_output_accuracy: 0.9849 - reg_output_mae: 0.0785 - val_loss: 0.1357 - val_class_output_loss: 0.4750 - val_reg_output_loss: 0.0882 - val_class_output_accuracy: 0.9363 - val_reg_output_mae: 0.1104
# Epoch 15/60
# 230/230 [==============================] - 72s 313ms/step - loss: 0.0465 - class_output_loss: 0.0380 - reg_output_loss: 0.0427 - class_output_accuracy: 0.9879 - reg_output_mae: 0.0823 - val_loss: 0.1279 - val_class_output_loss: 0.4155 - val_reg_output_loss: 0.0864 - val_class_output_accuracy: 0.9371 - val_reg_output_mae: 0.1109
# Epoch 16/60
# 230/230 [==============================] - 71s 307ms/step - loss: 0.0360 - class_output_loss: 0.0059 - reg_output_loss: 0.0354 - class_output_accuracy: 0.9983 - reg_output_mae: 0.0773 - val_loss: 0.1279 - val_class_output_loss: 0.4501 - val_reg_output_loss: 0.0829 - val_class_output_accuracy: 0.9419 - val_reg_output_mae: 0.1002
# Epoch 17/60
# 230/230 [==============================] - 71s 309ms/step - loss: 0.0417 - class_output_loss: 0.0045 - reg_output_loss: 0.0413 - class_output_accuracy: 0.9986 - reg_output_mae: 0.0822 - val_loss: 0.1297 - val_class_output_loss: 0.4702 - val_reg_output_loss: 0.0827 - val_class_output_accuracy: 0.9398 - val_reg_output_mae: 0.1065
# Epoch 18/60
# 230/230 [==============================] - 71s 310ms/step - loss: 0.0402 - class_output_loss: 0.0026 - reg_output_loss: 0.0400 - class_output_accuracy: 0.9992 - reg_output_mae: 0.0801 - val_loss: 0.1305 - val_class_output_loss: 0.4671 - val_reg_output_loss: 0.0838 - val_class_output_accuracy: 0.9430 - val_reg_output_mae: 0.1055
# Epoch 19/60
# 230/230 [==============================] - 71s 309ms/step - loss: 0.0382 - class_output_loss: 7.8391e-04 - reg_output_loss: 0.0382 - class_output_accuracy: 0.9999 - reg_output_mae: 0.0772 - val_loss: 0.1321 - val_class_output_loss: 0.4742 - val_reg_output_loss: 0.0847 - val_class_output_accuracy: 0.9416 - val_reg_output_mae: 0.1001
# Epoch 20/60
# 230/230 [==============================] - 71s 308ms/step - loss: 0.0376 - class_output_loss: 0.0011 - reg_output_loss: 0.0375 - class_output_accuracy: 0.9998 - reg_output_mae: 0.0762 - val_loss: 0.1285 - val_class_output_loss: 0.4523 - val_reg_output_loss: 0.0833 - val_class_output_accuracy: 0.9390 - val_reg_output_mae: 0.1034
# Epoch 21/60
# 230/230 [==============================] - 71s 310ms/step - loss: 0.0368 - class_output_loss: 0.0068 - reg_output_loss: 0.0362 - class_output_accuracy: 0.9979 - reg_output_mae: 0.0760 - val_loss: 0.1349 - val_class_output_loss: 0.4965 - val_reg_output_loss: 0.0853 - val_class_output_accuracy: 0.9376 - val_reg_output_mae: 0.1014
# Epoch 22/60
# 230/230 [==============================] - 72s 313ms/step - loss: 0.0421 - class_output_loss: 0.0139 - reg_output_loss: 0.0408 - class_output_accuracy: 0.9952 - reg_output_mae: 0.0811 - val_loss: 0.1305 - val_class_output_loss: 0.4845 - val_reg_output_loss: 0.0820 - val_class_output_accuracy: 0.9370 - val_reg_output_mae: 0.1002
# Epoch 23/60
# 230/230 [==============================] - 72s 311ms/step - loss: 0.0373 - class_output_loss: 0.0037 - reg_output_loss: 0.0370 - class_output_accuracy: 0.9990 - reg_output_mae: 0.0769 - val_loss: 0.1339 - val_class_output_loss: 0.4841 - val_reg_output_loss: 0.0855 - val_class_output_accuracy: 0.9431 - val_reg_output_mae: 0.1037
# Epoch 24/60
# 230/230 [==============================] - 71s 309ms/step - loss: 0.0397 - class_output_loss: 0.0029 - reg_output_loss: 0.0394 - class_output_accuracy: 0.9992 - reg_output_mae: 0.0797 - val_loss: 0.1369 - val_class_output_loss: 0.4977 - val_reg_output_loss: 0.0872 - val_class_output_accuracy: 0.9422 - val_reg_output_mae: 0.1056
# Epoch 25/60
# 230/230 [==============================] - 72s 313ms/step - loss: 0.0381 - class_output_loss: 0.0030 - reg_output_loss: 0.0378 - class_output_accuracy: 0.9992 - reg_output_mae: 0.0769 - val_loss: 0.1314 - val_class_output_loss: 0.4784 - val_reg_output_loss: 0.0836 - val_class_output_accuracy: 0.9425 - val_reg_output_mae: 0.1045
# Epoch 26/60
# 230/230 [==============================] - 71s 308ms/step - loss: 0.0363 - class_output_loss: 3.9359e-04 - reg_output_loss: 0.0363 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0747 - val_loss: 0.1323 - val_class_output_loss: 0.4851 - val_reg_output_loss: 0.0838 - val_class_output_accuracy: 0.9438 - val_reg_output_mae: 0.1002
# Epoch 27/60
# 230/230 [==============================] - 72s 314ms/step - loss: 0.0375 - class_output_loss: 1.8945e-04 - reg_output_loss: 0.0375 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0768 - val_loss: 0.1319 - val_class_output_loss: 0.4891 - val_reg_output_loss: 0.0829 - val_class_output_accuracy: 0.9438 - val_reg_output_mae: 0.1008
# Epoch 28/60
# 230/230 [==============================] - 70s 307ms/step - loss: 0.0349 - class_output_loss: 2.4527e-04 - reg_output_loss: 0.0348 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0743 - val_loss: 0.1354 - val_class_output_loss: 0.4969 - val_reg_output_loss: 0.0857 - val_class_output_accuracy: 0.9425 - val_reg_output_mae: 0.1002
# Epoch 29/60
# 230/230 [==============================] - 70s 306ms/step - loss: 0.0333 - class_output_loss: 2.2314e-04 - reg_output_loss: 0.0333 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0718 - val_loss: 0.1340 - val_class_output_loss: 0.4963 - val_reg_output_loss: 0.0844 - val_class_output_accuracy: 0.9417 - val_reg_output_mae: 0.0993
# Epoch 30/60
# 230/230 [==============================] - 70s 306ms/step - loss: 0.0379 - class_output_loss: 0.0379 - reg_output_loss: 0.0342 - class_output_accuracy: 0.9898 - reg_output_mae: 0.0721 - val_loss: 0.1269 - val_class_output_loss: 0.4530 - val_reg_output_loss: 0.0816 - val_class_output_accuracy: 0.9315 - val_reg_output_mae: 0.0951
# Epoch 31/60
# 230/230 [==============================] - 73s 316ms/step - loss: 0.0404 - class_output_loss: 0.0218 - reg_output_loss: 0.0382 - class_output_accuracy: 0.9929 - reg_output_mae: 0.0773 - val_loss: 0.1324 - val_class_output_loss: 0.4676 - val_reg_output_loss: 0.0856 - val_class_output_accuracy: 0.9357 - val_reg_output_mae: 0.1021
# Epoch 32/60
# 230/230 [==============================] - 70s 307ms/step - loss: 0.0351 - class_output_loss: 0.0056 - reg_output_loss: 0.0345 - class_output_accuracy: 0.9982 - reg_output_mae: 0.0731 - val_loss: 0.1337 - val_class_output_loss: 0.4875 - val_reg_output_loss: 0.0850 - val_class_output_accuracy: 0.9429 - val_reg_output_mae: 0.0971
# Epoch 33/60
# 230/230 [==============================] - 71s 307ms/step - loss: 0.0342 - class_output_loss: 0.0023 - reg_output_loss: 0.0340 - class_output_accuracy: 0.9996 - reg_output_mae: 0.0732 - val_loss: 0.1335 - val_class_output_loss: 0.4779 - val_reg_output_loss: 0.0857 - val_class_output_accuracy: 0.9386 - val_reg_output_mae: 0.0927
# Epoch 34/60
# 230/230 [==============================] - 71s 308ms/step - loss: 0.0409 - class_output_loss: 5.9313e-04 - reg_output_loss: 0.0409 - class_output_accuracy: 0.9999 - reg_output_mae: 0.0830 - val_loss: 0.1313 - val_class_output_loss: 0.4872 - val_reg_output_loss: 0.0825 - val_class_output_accuracy: 0.9421 - val_reg_output_mae: 0.0993
# Epoch 35/60
# 230/230 [==============================] - 70s 307ms/step - loss: 0.0335 - class_output_loss: 2.0810e-04 - reg_output_loss: 0.0335 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0741 - val_loss: 0.1366 - val_class_output_loss: 0.4917 - val_reg_output_loss: 0.0875 - val_class_output_accuracy: 0.9420 - val_reg_output_mae: 0.1017
# Epoch 36/60
# 230/230 [==============================] - 71s 309ms/step - loss: 0.0357 - class_output_loss: 1.5708e-04 - reg_output_loss: 0.0357 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0745 - val_loss: 0.1335 - val_class_output_loss: 0.4974 - val_reg_output_loss: 0.0838 - val_class_output_accuracy: 0.9423 - val_reg_output_mae: 0.0967
# Epoch 37/60
# 230/230 [==============================] - 71s 310ms/step - loss: 0.0355 - class_output_loss: 1.3578e-04 - reg_output_loss: 0.0355 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0769 - val_loss: 0.1373 - val_class_output_loss: 0.5019 - val_reg_output_loss: 0.0871 - val_class_output_accuracy: 0.9422 - val_reg_output_mae: 0.1038
# Epoch 38/60
# 230/230 [==============================] - 72s 311ms/step - loss: 0.0360 - class_output_loss: 1.0373e-04 - reg_output_loss: 0.0360 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0757 - val_loss: 0.1354 - val_class_output_loss: 0.5061 - val_reg_output_loss: 0.0848 - val_class_output_accuracy: 0.9423 - val_reg_output_mae: 0.0977
# Epoch 39/60
# 230/230 [==============================] - 72s 312ms/step - loss: 0.0363 - class_output_loss: 9.6581e-05 - reg_output_loss: 0.0363 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0739 - val_loss: 0.1343 - val_class_output_loss: 0.5105 - val_reg_output_loss: 0.0832 - val_class_output_accuracy: 0.9425 - val_reg_output_mae: 0.0945
# Epoch 40/60
# 230/230 [==============================] - 71s 310ms/step - loss: 0.0336 - class_output_loss: 8.5145e-05 - reg_output_loss: 0.0336 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0707 - val_loss: 0.1404 - val_class_output_loss: 0.5143 - val_reg_output_loss: 0.0890 - val_class_output_accuracy: 0.9427 - val_reg_output_mae: 0.1096
# Epoch 41/60
# 230/230 [==============================] - 71s 309ms/step - loss: 0.0334 - class_output_loss: 0.0021 - reg_output_loss: 0.0332 - class_output_accuracy: 0.9998 - reg_output_mae: 0.0711 - val_loss: 0.1349 - val_class_output_loss: 0.5086 - val_reg_output_loss: 0.0841 - val_class_output_accuracy: 0.9371 - val_reg_output_mae: 0.0988
# Epoch 42/60
# 230/230 [==============================] - 71s 310ms/step - loss: 0.0386 - class_output_loss: 0.0349 - reg_output_loss: 0.0351 - class_output_accuracy: 0.9890 - reg_output_mae: 0.0739 - val_loss: 0.1311 - val_class_output_loss: 0.4670 - val_reg_output_loss: 0.0844 - val_class_output_accuracy: 0.9360 - val_reg_output_mae: 0.0992
# Epoch 43/60
# 230/230 [==============================] - 71s 311ms/step - loss: 0.0367 - class_output_loss: 0.0144 - reg_output_loss: 0.0352 - class_output_accuracy: 0.9956 - reg_output_mae: 0.0721 - val_loss: 0.1375 - val_class_output_loss: 0.5289 - val_reg_output_loss: 0.0846 - val_class_output_accuracy: 0.9375 - val_reg_output_mae: 0.1005
# Epoch 44/60
# 230/230 [==============================] - 71s 308ms/step - loss: 0.0367 - class_output_loss: 0.0089 - reg_output_loss: 0.0358 - class_output_accuracy: 0.9972 - reg_output_mae: 0.0720 - val_loss: 0.1384 - val_class_output_loss: 0.4957 - val_reg_output_loss: 0.0888 - val_class_output_accuracy: 0.9399 - val_reg_output_mae: 0.1028
# Epoch 45/60
# 230/230 [==============================] - 71s 307ms/step - loss: 0.0364 - class_output_loss: 0.0010 - reg_output_loss: 0.0363 - class_output_accuracy: 0.9997 - reg_output_mae: 0.0753 - val_loss: 0.1329 - val_class_output_loss: 0.4928 - val_reg_output_loss: 0.0836 - val_class_output_accuracy: 0.9394 - val_reg_output_mae: 0.1046
# Epoch 46/60
# 230/230 [==============================] - 71s 309ms/step - loss: 0.0360 - class_output_loss: 2.6799e-04 - reg_output_loss: 0.0360 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0742 - val_loss: 0.1356 - val_class_output_loss: 0.4998 - val_reg_output_loss: 0.0856 - val_class_output_accuracy: 0.9416 - val_reg_output_mae: 0.1049
# Epoch 47/60
# 230/230 [==============================] - 71s 309ms/step - loss: 0.0348 - class_output_loss: 1.7408e-04 - reg_output_loss: 0.0347 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0736 - val_loss: 0.1385 - val_class_output_loss: 0.5007 - val_reg_output_loss: 0.0884 - val_class_output_accuracy: 0.9417 - val_reg_output_mae: 0.0992
# Epoch 48/60
# 230/230 [==============================] - 71s 310ms/step - loss: 0.0346 - class_output_loss: 1.1910e-04 - reg_output_loss: 0.0346 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0737 - val_loss: 0.1375 - val_class_output_loss: 0.5060 - val_reg_output_loss: 0.0869 - val_class_output_accuracy: 0.9416 - val_reg_output_mae: 0.0993
# Epoch 49/60
# 230/230 [==============================] - 71s 308ms/step - loss: 0.0372 - class_output_loss: 1.0148e-04 - reg_output_loss: 0.0372 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0754 - val_loss: 0.1374 - val_class_output_loss: 0.5084 - val_reg_output_loss: 0.0865 - val_class_output_accuracy: 0.9417 - val_reg_output_mae: 0.1057
# Epoch 50/60
# 230/230 [==============================] - 70s 305ms/step - loss: 0.0355 - class_output_loss: 9.0721e-05 - reg_output_loss: 0.0355 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0739 - val_loss: 0.1364 - val_class_output_loss: 0.5127 - val_reg_output_loss: 0.0851 - val_class_output_accuracy: 0.9419 - val_reg_output_mae: 0.0952
# Epoch 51/60
# 230/230 [==============================] - 73s 318ms/step - loss: 0.0367 - class_output_loss: 7.9770e-05 - reg_output_loss: 0.0367 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0759 - val_loss: 0.1367 - val_class_output_loss: 0.5166 - val_reg_output_loss: 0.0850 - val_class_output_accuracy: 0.9416 - val_reg_output_mae: 0.0974
# Epoch 52/60
# 230/230 [==============================] - 73s 317ms/step - loss: 0.0382 - class_output_loss: 7.4647e-05 - reg_output_loss: 0.0382 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0760 - val_loss: 0.1397 - val_class_output_loss: 0.5180 - val_reg_output_loss: 0.0879 - val_class_output_accuracy: 0.9415 - val_reg_output_mae: 0.1006
# Epoch 53/60
# 230/230 [==============================] - 72s 312ms/step - loss: 0.0360 - class_output_loss: 6.1804e-05 - reg_output_loss: 0.0360 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0727 - val_loss: 0.1391 - val_class_output_loss: 0.5227 - val_reg_output_loss: 0.0868 - val_class_output_accuracy: 0.9415 - val_reg_output_mae: 0.1042
# Epoch 54/60
# 230/230 [==============================] - 71s 310ms/step - loss: 0.0355 - class_output_loss: 5.8642e-05 - reg_output_loss: 0.0355 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0739 - val_loss: 0.1370 - val_class_output_loss: 0.5218 - val_reg_output_loss: 0.0848 - val_class_output_accuracy: 0.9417 - val_reg_output_mae: 0.0990
# Epoch 55/60
# 230/230 [==============================] - 71s 310ms/step - loss: 0.0368 - class_output_loss: 5.2037e-05 - reg_output_loss: 0.0368 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0746 - val_loss: 0.1388 - val_class_output_loss: 0.5258 - val_reg_output_loss: 0.0863 - val_class_output_accuracy: 0.9417 - val_reg_output_mae: 0.1005
# Epoch 56/60
# 230/230 [==============================] - 71s 309ms/step - loss: 0.0352 - class_output_loss: 4.6904e-05 - reg_output_loss: 0.0352 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0718 - val_loss: 0.1401 - val_class_output_loss: 0.5311 - val_reg_output_loss: 0.0870 - val_class_output_accuracy: 0.9424 - val_reg_output_mae: 0.1009
# Epoch 57/60
# 230/230 [==============================] - 73s 316ms/step - loss: 0.0365 - class_output_loss: 4.5317e-05 - reg_output_loss: 0.0365 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0758 - val_loss: 0.1402 - val_class_output_loss: 0.5318 - val_reg_output_loss: 0.0871 - val_class_output_accuracy: 0.9417 - val_reg_output_mae: 0.0981
# Epoch 58/60
# 230/230 [==============================] - 71s 309ms/step - loss: 0.0349 - class_output_loss: 3.8420e-05 - reg_output_loss: 0.0349 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0709 - val_loss: 0.1409 - val_class_output_loss: 0.5322 - val_reg_output_loss: 0.0876 - val_class_output_accuracy: 0.9415 - val_reg_output_mae: 0.0990
# Epoch 59/60
# 230/230 [==============================] - 71s 308ms/step - loss: 0.0391 - class_output_loss: 3.7629e-05 - reg_output_loss: 0.0391 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0758 - val_loss: 0.1395 - val_class_output_loss: 0.5347 - val_reg_output_loss: 0.0860 - val_class_output_accuracy: 0.9422 - val_reg_output_mae: 0.1089
# Epoch 60/60
# 230/230 [==============================] - 71s 308ms/step - loss: 0.0369 - class_output_loss: 3.9962e-05 - reg_output_loss: 0.0369 - class_output_accuracy: 1.0000 - reg_output_mae: 0.0737 - val_loss: 0.1390 - val_class_output_loss: 0.5406 - val_reg_output_loss: 0.0849 - val_class_output_accuracy: 0.9425 - val_reg_output_mae: 0.1017

# %%
N = 60
plt.style.use("ggplot")
plt.figure()
#plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["class_output_loss"], label="train_class_loss")
plt.plot(np.arange(0, N), H.history["reg_output_loss"], label="train_reg_loss")
plt.plot(np.arange(0, N), H.history["class_output_accuracy"], label="train_accuracy")
plt.plot(np.arange(0, N), H.history["reg_output_mae"], label="train_mae")
#plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["val_class_output_loss"], label="val_class_loss")
plt.plot(np.arange(0, N), H.history["val_reg_output_loss"], label="val_reg_loss")
plt.plot(np.arange(0, N), H.history["val_class_output_accuracy"], label="val_accuracy")
plt.plot(np.arange(0, N), H.history["val_reg_output_mae"], label="val_mae")
plt.title("Training Loss and MAE")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.show()

# %%
#model = load_model("annotations_best.h5")
img_test = cv2.imread(r'gc10det/oil_spot/oil_spot (100).jpg')
img_test = cv2.resize(img_test, (w, l))
img_test = [img_test]
img_test = np.array(img_test, dtype = 'float')
img_test /= 255
p=model.predict(img_test)
print(p[0][0][1])
#print(get_annotations("lable/water_spot (70).xml"))
# Out:
# 1/1 [==============================] - 0s 105ms/step
# [4.0394323e-32 1.9034624e-24 1.0645186e-20 4.2521125e-24 1.4940414e-02
#  5.1419630e-14 6.1313598e-25 8.6878343e-17 3.9290960e-32 2.0377306e-29
#  3.1647447e-28 2.8026728e-22]

# %%
def img_format(img):
    imgf = cv2.imread(img)
    imgf = cv2.resize(imgf, (w, l))
    imgf = [imgf]
    imgf = np.array(imgf, dtype = 'float')
    imgf /= 255
    return imgf

# %%
a = get_annotations(r'gc10det/water_spot/water_spot (50).jpg')
print(a)
# Out:
# 0

# %%
data_dir = 'gc10det'
class_names = sorted([subdir for subdir in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, subdir))])
num_classes = len(class_names)
#print(class_names[11])
for i in range(len(class_names)):
    for j in range(len(class_names[i])):
        img= f'gc10det/{class_names[i]}/{class_names[i]} ({j}).jpg'
        print(img)
# Out:
# gc10det/crease/crease (0).jpg
# gc10det/crease/crease (1).jpg
# gc10det/crease/crease (2).jpg
# gc10det/crease/crease (3).jpg
# gc10det/crease/crease (4).jpg
# gc10det/crease/crease (5).jpg
# gc10det/crescent_gap/crescent_gap (0).jpg
# gc10det/crescent_gap/crescent_gap (1).jpg
# gc10det/crescent_gap/crescent_gap (2).jpg
# gc10det/crescent_gap/crescent_gap (3).jpg
# gc10det/crescent_gap/crescent_gap (4).jpg
# gc10det/crescent_gap/crescent_gap (5).jpg
# gc10det/crescent_gap/crescent_gap (6).jpg
# gc10det/crescent_gap/crescent_gap (7).jpg
# gc10det/crescent_gap/crescent_gap (8).jpg
# gc10det/crescent_gap/crescent_gap (9).jpg
# gc10det/crescent_gap/crescent_gap (10).jpg
# gc10det/crescent_gap/crescent_gap (11).jpg
# gc10det/inclusion/inclusion (0).jpg
# gc10det/inclusion/inclusion (1).jpg
# gc10det/inclusion/inclusion (2).jpg
# gc10det/inclusion/inclusion (3).jpg
# gc10det/inclusion/inclusion (4).jpg
# gc10det/inclusion/inclusion (5).jpg
# gc10det/inclusion/inclusion (6).jpg
# gc10det/inclusion/inclusion (7).jpg
# gc10det/inclusion/inclusion (8).jpg
# gc10det/oil_spot/oil_spot (0).jpg
# gc10det/oil_spot/oil_spot (1).jpg
# gc10det/oil_spot/oil_spot (2).jpg
# gc10det/oil_spot/oil_spot (3).jpg
# gc10det/oil_spot/oil_spot (4).jpg
# gc10det/oil_spot/oil_spot (5).jpg
# gc10det/oil_spot/oil_spot (6).jpg
# gc10det/oil_spot/oil_spot (7).jpg
# gc10det/punching_hole/punching_hole (0).jpg
# gc10det/punching_hole/punching_hole (1).jpg
# gc10det/punching_hole/punching_hole (2).jpg
# gc10det/punching_hole/punching_hole (3).jpg
# gc10det/punching_hole/punching_hole (4).jpg
# gc10det/punching_hole/punching_hole (5).jpg
# gc10det/punching_hole/punching_hole (6).jpg
# gc10det/punching_hole/punching_hole (7).jpg
# gc10det/punching_hole/punching_hole (8).jpg
# gc10det/punching_hole/punching_hole (9).jpg
# gc10det/punching_hole/punching_hole (10).jpg
# gc10det/punching_hole/punching_hole (11).jpg
# gc10det/punching_hole/punching_hole (12).jpg
# gc10det/rolled_in_scale/rolled_in_scale (0).jpg
# gc10det/rolled_in_scale/rolled_in_scale (1).jpg
# gc10det/rolled_in_scale/rolled_in_scale (2).jpg
# gc10det/rolled_in_scale/rolled_in_scale (3).jpg
# gc10det/rolled_in_scale/rolled_in_scale (4).jpg
# gc10det/rolled_in_scale/rolled_in_scale (5).jpg
# gc10det/rolled_in_scale/rolled_in_scale (6).jpg
# gc10det/rolled_in_scale/rolled_in_scale (7).jpg
# gc10det/rolled_in_scale/rolled_in_scale (8).jpg
# gc10det/rolled_in_scale/rolled_in_scale (9).jpg
# gc10det/rolled_in_scale/rolled_in_scale (10).jpg
# gc10det/rolled_in_scale/rolled_in_scale (11).jpg
# gc10det/rolled_in_scale/rolled_in_scale (12).jpg
# gc10det/rolled_in_scale/rolled_in_scale (13).jpg
# gc10det/rolled_in_scale/rolled_in_scale (14).jpg
# gc10det/rolled_pit/rolled_pit (0).jpg
# gc10det/rolled_pit/rolled_pit (1).jpg
# gc10det/rolled_pit/rolled_pit (2).jpg
# gc10det/rolled_pit/rolled_pit (3).jpg
# gc10det/rolled_pit/rolled_pit (4).jpg
# gc10det/rolled_pit/rolled_pit (5).jpg
# gc10det/rolled_pit/rolled_pit (6).jpg
# gc10det/rolled_pit/rolled_pit (7).jpg
# gc10det/rolled_pit/rolled_pit (8).jpg
# gc10det/rolled_pit/rolled_pit (9).jpg
# gc10det/scratches/scratches (0).jpg
# gc10det/scratches/scratches (1).jpg
# gc10det/scratches/scratches (2).jpg
# gc10det/scratches/scratches (3).jpg
# gc10det/scratches/scratches (4).jpg
# gc10det/scratches/scratches (5).jpg
# gc10det/scratches/scratches (6).jpg
# gc10det/scratches/scratches (7).jpg
# gc10det/scratches/scratches (8).jpg
# gc10det/silk_spot/silk_spot (0).jpg
# gc10det/silk_spot/silk_spot (1).jpg
# gc10det/silk_spot/silk_spot (2).jpg
# gc10det/silk_spot/silk_spot (3).jpg
# gc10det/silk_spot/silk_spot (4).jpg
# gc10det/silk_spot/silk_spot (5).jpg
# gc10det/silk_spot/silk_spot (6).jpg
# gc10det/silk_spot/silk_spot (7).jpg
# gc10det/silk_spot/silk_spot (8).jpg
# gc10det/waist_folding/waist_folding (0).jpg
# gc10det/waist_folding/waist_folding (1).jpg
# gc10det/waist_folding/waist_folding (2).jpg
# gc10det/waist_folding/waist_folding (3).jpg
# gc10det/waist_folding/waist_folding (4).jpg
# gc10det/waist_folding/waist_folding (5).jpg
# gc10det/waist_folding/waist_folding (6).jpg
# gc10det/waist_folding/waist_folding (7).jpg
# gc10det/waist_folding/waist_folding (8).jpg
# gc10det/waist_folding/waist_folding (9).jpg
# gc10det/waist_folding/waist_folding (10).jpg
# gc10det/waist_folding/waist_folding (11).jpg
# gc10det/waist_folding/waist_folding (12).jpg
# gc10det/water_spot/water_spot (0).jpg
# gc10det/water_spot/water_spot (1).jpg
# gc10det/water_spot/water_spot (2).jpg
# gc10det/water_spot/water_spot (3).jpg
# gc10det/water_spot/water_spot (4).jpg
# gc10det/water_spot/water_spot (5).jpg
# gc10det/water_spot/water_spot (6).jpg
# gc10det/water_spot/water_spot (7).jpg
# gc10det/water_spot/water_spot (8).jpg
# gc10det/water_spot/water_spot (9).jpg
# gc10det/welding_line/welding_line (0).jpg
# gc10det/welding_line/welding_line (1).jpg
# gc10det/welding_line/welding_line (2).jpg
# gc10det/welding_line/welding_line (3).jpg
# gc10det/welding_line/welding_line (4).jpg
# gc10det/welding_line/welding_line (5).jpg
# gc10det/welding_line/welding_line (6).jpg
# gc10det/welding_line/welding_line (7).jpg
# gc10det/welding_line/welding_line (8).jpg
# gc10det/welding_line/welding_line (9).jpg
# gc10det/welding_line/welding_line (10).jpg
# gc10det/welding_line/welding_line (11).jpg

# %%
def extract_min(lst, index):
    minn = 10000000
    for i in range(len(lst)):
        for j in range(len(lst[i])):
            if lst[i][j][index] < minn:
                minn = lst[i][j][index]
    return minn

def extract_max(lst, index):
    maxx = -10000000
    for i in range(len(lst)):
        for j in range(len(lst[i])):
            if lst[i][j][index] > maxx:
                maxx = lst[i][j][index]
    return maxx

# %%
def inv_minmax_scaler(val, minn, maxx):
    return ((val *(maxx-minn))+ minn)

# %%
def pltt(img):
    for i in range(11):
        if (pred[1][0][i][0]<0):
            continue
        name = np.argmax(pred[0][0][i])
        xmin = inv_minmax_scaler(pred[1][0][i][0], xmin_min, xmin_max)
        ymin = inv_minmax_scaler(pred[1][0][i][1], ymin_min, ymin_max)
        xmax = inv_minmax_scaler(pred[1][0][i][2], xmax_min, xmax_max)
        ymax = inv_minmax_scaler(pred[1][0][i][3], ymax_min, ymax_max)
        #print(xmin, ymin, xmax, ymax)
        
        width_rec = xmax-xmin
        height_rec= ymax-ymin




        rect = plt.Rectangle((xmin, ymin), width_rec, height_rec, fill=False, edgecolor='red')
        ax.add_patch(rect)
        plt.text(xmin+width_rec/2, ymin+height_rec/2, 'pred', color='red', ha='center', va='center')
        plt.text(xmin, ymin, mapping2.get(name, "Unknown") , color='red', ha='center', va='bottom')

# %%
def plot(img_path, real, pred):
    img = cv2.imread(img_path)
    img = cv2.resize(img, (w, l))
    img = np.array(img)

    fig, ax = plt.subplots(figsize=(10, 10))
    ax.imshow(img, cmap = 'gray')
    
    for i in range(11):
        if (pred[1][0][i][0]<0):
            continue
        name = np.argmax(pred[0][0][i])
        xmin = inv_minmax_scaler(pred[1][0][i][0], xmin_min, xmin_max)
        ymin = inv_minmax_scaler(pred[1][0][i][1], ymin_min, ymin_max)
        xmax = inv_minmax_scaler(pred[1][0][i][2], xmax_min, xmax_max)
        ymax = inv_minmax_scaler(pred[1][0][i][3], ymax_min, ymax_max)
        #print(xmin, ymin, xmax, ymax)
        
        width_rec = xmax-xmin
        height_rec= ymax-ymin




        rect = plt.Rectangle((xmin, ymin), width_rec, height_rec, fill=False, edgecolor='red')
        ax.add_patch(rect)
        plt.text(xmin+width_rec/2, ymin+height_rec/2, 'pred', color='red', ha='center', va='center')
        plt.text(xmin, ymin, mapping2.get(name, "Unknown") , color='red', ha='center', va='bottom')

    
    for i in range(len(real)):
        name = real[i][0]
        xmin = real[i][1]
        ymin = real[i][2]
        xmax = real[i][3]
        ymax = real[i][4]
    
        #print(xmin, ymin, xmax, ymax)
        width_rec = xmax - xmin
        height_rec = ymax - ymin

        rect2 = plt.Rectangle((xmin, ymin), width_rec, height_rec, fill=False, edgecolor='blue')
        ax.add_patch(rect2)
        plt.text(xmin+width_rec/2, ymin+height_rec/2, 'real', color='blue', ha='center', va='center')
        plt.text(xmin, ymin, mapping2.get(name, "Unknown"), color='blue', ha='center', va='bottom')

    plt.show()

# %%
# img = r'gc10det/oil_spot/oil_spot (32).jpg'
# annot = "lable/oil_spot (32).xml"
# preds = model.predict(img_format(img))
# print(preds)
# print(get_annotations(annot))
# plot(img, get_annotations(annot), preds)

# %%
# for i in range(len(x_test)):
#     x_test = x_test[i]
#     real_val= y_test[i]
#     random_img= X[i]
#     random_img=[random_img]
#     random_img = np.array(random_img, dtype = 'float')
#     random_img/=255
#     prediction = model.predict(random_img)
#     yhat = np.argmax(prediction)
#     predictions.append(yhat)
#     if yhat!= real_val:
#         incorrect_predictions+=1
        
# print(incorrect_predictions)
# print(DataSet_length)
# tf.math.confusion_matrix(y, predictions)
