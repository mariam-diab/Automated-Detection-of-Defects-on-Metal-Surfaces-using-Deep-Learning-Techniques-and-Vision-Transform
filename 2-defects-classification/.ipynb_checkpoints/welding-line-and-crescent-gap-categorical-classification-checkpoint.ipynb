# %%
# import zipfile
# with zipfile.ZipFile('archive (1).zip', 'r') as zip_ref:
#     zip_ref.extractall('data/raw')

# %%
cd "C:\\Users\\Toqa Alaa\\PBL2\\gc10det"
# Out:
# C:\Users\Toqa Alaa\PBL2\gc10det

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Flatten
from keras.utils import np_utils
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import os

# %%
X = []
y = []
X_train = []
y_train = []
X_test = []
y_test = []
w = 56
l = 56

# %%
fig = plt.figure(figsize=(10, 10))
for i in range(1, 6):
    img = cv2.imread(fr'welding_line/welding_line ({i}).jpg')
    img = cv2.resize(img, (56, 56))
    fig.add_subplot(2, 5, i)
    plt.imshow(img, aspect = 'auto')
    plt.grid(False)
for i in range(6,11):
    img = cv2.imread(fr'crescent_gap/crescent_gap ({i}).jpg')
    img = cv2.resize(img, (56, 56))
    fig.add_subplot(2, 5, i)
    plt.imshow(img, aspect = 'auto')
    plt.grid(False)
plt.show()

print(img.shape)
# Out:
# (56, 56, 3)

# %%
for i in range(1, 273):
    img = cv2.imread(fr'welding_line/welding_line ({i}).jpg')
    img = cv2.resize(img, (l, w))
    X.append(img)
    y.append(0)

for i in range(1, 226):
    img = cv2.imread(fr'crescent_gap/crescent_gap ({i}).jpg')
    img = cv2.resize(img, (l, w))
    X.append(img)
    y.append(1)

# %%
from sklearn.model_selection import train_test_split
import numpy as np

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size= 0.3)
x_train = np.array(x_train, dtype = 'float')
y_train = np.array(y_train, dtype = 'float').astype('float32').reshape((-1,1))
x_test = np.array(x_test, dtype = 'float')
y_test = np.array(y_test, dtype = 'float').astype('float32').reshape((-1,1))

# %%
n_classes = 2

x_train /= 255
x_test /= 255
y_train = np_utils.to_categorical(y_train, n_classes)
y_test = np_utils.to_categorical(y_test, n_classes)

# %%
model = Sequential()
model.add(Conv2D(56, kernel_size=(2,2), strides=(1,1), padding='valid', activation='relu', input_shape=(56,56,3)))
model.add(MaxPool2D(pool_size=(1,1)))

model.add(Flatten())

model.add(Dense(120, activation='relu'))
model.add(Dense(90, activation='relu'))
model.add(Dense(120, activation='relu'))
model.add(Dense(90, activation='relu'))

model.add(Dense(2, activation='sigmoid'))

model.compile(loss = 'binary_crossentropy', metrics = ['accuracy'], optimizer = 'adam')

# %%
N = 100

H = model.fit(x_train, y_train, batch_size = 10, epochs = N, validation_data = (x_test, y_test))
# Out:
# Epoch 1/100
# 54/54 [==============================] - 10s 18ms/step - loss: 0.5897 - accuracy: 0.7069 - val_loss: 0.4417 - val_accuracy: 0.7792
# Epoch 2/100
# 54/54 [==============================] - 1s 10ms/step - loss: 0.4229 - accuracy: 0.7755 - val_loss: 0.4693 - val_accuracy: 0.7359
# Epoch 3/100
# 54/54 [==============================] - 0s 9ms/step - loss: 0.3664 - accuracy: 0.8256 - val_loss: 0.3773 - val_accuracy: 0.8268
# Epoch 4/100
# 54/54 [==============================] - 0s 9ms/step - loss: 0.2924 - accuracy: 0.8942 - val_loss: 0.3625 - val_accuracy: 0.8571
# Epoch 5/100
# 54/54 [==============================] - 0s 9ms/step - loss: 0.2214 - accuracy: 0.9109 - val_loss: 0.3307 - val_accuracy: 0.8701
# Epoch 6/100
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1326 - accuracy: 0.9629 - val_loss: 0.4637 - val_accuracy: 0.8528
# Epoch 7/100
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1010 - accuracy: 0.9703 - val_loss: 0.4108 - val_accuracy: 0.8701
# Epoch 8/100
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0886 - accuracy: 0.9777 - val_loss: 0.4428 - val_accuracy: 0.8831
# Epoch 9/100
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0414 - accuracy: 0.9889 - val_loss: 0.5499 - val_accuracy: 0.8788
# Epoch 10/100
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0555 - accuracy: 0.9814 - val_loss: 0.4998 - val_accuracy: 0.8615
# Epoch 11/100
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0583 - accuracy: 0.9852 - val_loss: 0.5093 - val_accuracy: 0.8355
# Epoch 12/100
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0443 - accuracy: 0.9907 - val_loss: 0.6012 - val_accuracy: 0.8442
# Epoch 13/100
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0091 - accuracy: 0.9963 - val_loss: 0.8457 - val_accuracy: 0.8745
# Epoch 14/100
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0103 - accuracy: 0.9963 - val_loss: 0.8813 - val_accuracy: 0.8658
# Epoch 15/100
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0300 - accuracy: 0.9944 - val_loss: 0.6978 - val_accuracy: 0.8615
# Epoch 16/100
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0166 - accuracy: 0.9963 - val_loss: 1.1067 - val_accuracy: 0.8485
# Epoch 17/100
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0394 - accuracy: 0.9870 - val_loss: 0.9450 - val_accuracy: 0.8615
# Epoch 18/100
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0121 - accuracy: 0.9981 - val_loss: 1.1417 - val_accuracy: 0.8485
# Epoch 19/100
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0537 - accuracy: 0.9777 - val_loss: 1.6992 - val_accuracy: 0.8182
# Epoch 20/100
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0823 - accuracy: 0.9777 - val_loss: 0.6647 - val_accuracy: 0.8745
# Epoch 21/100
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.9496 - val_accuracy: 0.8745
# Epoch 22/100
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0045 - accuracy: 0.9981 - val_loss: 1.3128 - val_accuracy: 0.8528
# Epoch 23/100
# 54/54 [==============================] - 0s 9ms/step - loss: 2.1930e-04 - accuracy: 1.0000 - val_loss: 1.4211 - val_accuracy: 0.8658
# Epoch 24/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.1145e-04 - accuracy: 1.0000 - val_loss: 1.5034 - val_accuracy: 0.8615
# Epoch 25/100
# 54/54 [==============================] - 0s 9ms/step - loss: 6.5334e-05 - accuracy: 1.0000 - val_loss: 1.5573 - val_accuracy: 0.8615
# Epoch 26/100
# 54/54 [==============================] - 0s 9ms/step - loss: 4.7219e-05 - accuracy: 1.0000 - val_loss: 1.5937 - val_accuracy: 0.8615
# Epoch 27/100
# 54/54 [==============================] - 0s 9ms/step - loss: 3.7699e-05 - accuracy: 1.0000 - val_loss: 1.6257 - val_accuracy: 0.8615
# Epoch 28/100
# 54/54 [==============================] - 0s 9ms/step - loss: 3.0733e-05 - accuracy: 1.0000 - val_loss: 1.6576 - val_accuracy: 0.8615
# Epoch 29/100
# 54/54 [==============================] - 0s 9ms/step - loss: 2.6128e-05 - accuracy: 1.0000 - val_loss: 1.6871 - val_accuracy: 0.8615
# Epoch 30/100
# 54/54 [==============================] - 0s 9ms/step - loss: 2.2619e-05 - accuracy: 1.0000 - val_loss: 1.7072 - val_accuracy: 0.8615
# Epoch 31/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.8978e-05 - accuracy: 1.0000 - val_loss: 1.7318 - val_accuracy: 0.8615
# Epoch 32/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.6040e-05 - accuracy: 1.0000 - val_loss: 1.7595 - val_accuracy: 0.8615
# Epoch 33/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.3557e-05 - accuracy: 1.0000 - val_loss: 1.7878 - val_accuracy: 0.8615
# Epoch 34/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.0600e-05 - accuracy: 1.0000 - val_loss: 1.8222 - val_accuracy: 0.8615
# Epoch 35/100
# 54/54 [==============================] - 0s 9ms/step - loss: 8.6842e-06 - accuracy: 1.0000 - val_loss: 1.8561 - val_accuracy: 0.8615
# Epoch 36/100
# 54/54 [==============================] - 0s 9ms/step - loss: 7.5021e-06 - accuracy: 1.0000 - val_loss: 1.8790 - val_accuracy: 0.8615
# Epoch 37/100
# 54/54 [==============================] - 0s 9ms/step - loss: 6.4146e-06 - accuracy: 1.0000 - val_loss: 1.9039 - val_accuracy: 0.8615
# Epoch 38/100
# 54/54 [==============================] - 0s 9ms/step - loss: 5.8029e-06 - accuracy: 1.0000 - val_loss: 1.9210 - val_accuracy: 0.8615
# Epoch 39/100
# 54/54 [==============================] - 0s 9ms/step - loss: 5.1407e-06 - accuracy: 1.0000 - val_loss: 1.9372 - val_accuracy: 0.8615
# Epoch 40/100
# 54/54 [==============================] - 0s 9ms/step - loss: 4.5940e-06 - accuracy: 1.0000 - val_loss: 1.9597 - val_accuracy: 0.8615
# Epoch 41/100
# 54/54 [==============================] - 0s 9ms/step - loss: 4.2887e-06 - accuracy: 1.0000 - val_loss: 1.9815 - val_accuracy: 0.8615
# Epoch 42/100
# 54/54 [==============================] - 0s 9ms/step - loss: 3.9214e-06 - accuracy: 1.0000 - val_loss: 1.9947 - val_accuracy: 0.8615
# Epoch 43/100
# 54/54 [==============================] - 0s 9ms/step - loss: 3.5863e-06 - accuracy: 1.0000 - val_loss: 2.0059 - val_accuracy: 0.8615
# Epoch 44/100
# 54/54 [==============================] - 0s 9ms/step - loss: 3.3950e-06 - accuracy: 1.0000 - val_loss: 2.0198 - val_accuracy: 0.8615
# Epoch 45/100
# 54/54 [==============================] - 0s 9ms/step - loss: 3.0862e-06 - accuracy: 1.0000 - val_loss: 2.0372 - val_accuracy: 0.8615
# Epoch 46/100
# 54/54 [==============================] - 0s 9ms/step - loss: 2.8966e-06 - accuracy: 1.0000 - val_loss: 2.0486 - val_accuracy: 0.8615
# Epoch 47/100
# 54/54 [==============================] - 0s 9ms/step - loss: 2.6486e-06 - accuracy: 1.0000 - val_loss: 2.0645 - val_accuracy: 0.8615
# Epoch 48/100
# 54/54 [==============================] - 1s 9ms/step - loss: 2.4737e-06 - accuracy: 1.0000 - val_loss: 2.0774 - val_accuracy: 0.8615
# Epoch 49/100
# 54/54 [==============================] - 0s 9ms/step - loss: 2.3227e-06 - accuracy: 1.0000 - val_loss: 2.0897 - val_accuracy: 0.8615
# Epoch 50/100
# 54/54 [==============================] - 0s 9ms/step - loss: 2.2006e-06 - accuracy: 1.0000 - val_loss: 2.1038 - val_accuracy: 0.8615
# Epoch 51/100
# 54/54 [==============================] - 0s 9ms/step - loss: 2.0887e-06 - accuracy: 1.0000 - val_loss: 2.1127 - val_accuracy: 0.8615
# Epoch 52/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.9584e-06 - accuracy: 1.0000 - val_loss: 2.1254 - val_accuracy: 0.8615
# Epoch 53/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.8570e-06 - accuracy: 1.0000 - val_loss: 2.1352 - val_accuracy: 0.8615
# Epoch 54/100
# 54/54 [==============================] - 1s 9ms/step - loss: 1.7869e-06 - accuracy: 1.0000 - val_loss: 2.1435 - val_accuracy: 0.8615
# Epoch 55/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.6628e-06 - accuracy: 1.0000 - val_loss: 2.1576 - val_accuracy: 0.8615
# Epoch 56/100
# 54/54 [==============================] - 1s 9ms/step - loss: 1.5642e-06 - accuracy: 1.0000 - val_loss: 2.1660 - val_accuracy: 0.8615
# Epoch 57/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.5010e-06 - accuracy: 1.0000 - val_loss: 2.1779 - val_accuracy: 0.8615
# Epoch 58/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.4260e-06 - accuracy: 1.0000 - val_loss: 2.1881 - val_accuracy: 0.8615
# Epoch 59/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.3468e-06 - accuracy: 1.0000 - val_loss: 2.1954 - val_accuracy: 0.8615
# Epoch 60/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.2835e-06 - accuracy: 1.0000 - val_loss: 2.2065 - val_accuracy: 0.8615
# Epoch 61/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.2389e-06 - accuracy: 1.0000 - val_loss: 2.2249 - val_accuracy: 0.8615
# Epoch 62/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.1484e-06 - accuracy: 1.0000 - val_loss: 2.2242 - val_accuracy: 0.8615
# Epoch 63/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.1147e-06 - accuracy: 1.0000 - val_loss: 2.2350 - val_accuracy: 0.8615
# Epoch 64/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.0663e-06 - accuracy: 1.0000 - val_loss: 2.2456 - val_accuracy: 0.8615
# Epoch 65/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.0062e-06 - accuracy: 1.0000 - val_loss: 2.2540 - val_accuracy: 0.8615
# Epoch 66/100
# 54/54 [==============================] - 1s 9ms/step - loss: 9.5620e-07 - accuracy: 1.0000 - val_loss: 2.2645 - val_accuracy: 0.8615
# Epoch 67/100
# 54/54 [==============================] - 1s 9ms/step - loss: 9.2174e-07 - accuracy: 1.0000 - val_loss: 2.2761 - val_accuracy: 0.8615
# Epoch 68/100
# 54/54 [==============================] - 1s 9ms/step - loss: 8.8157e-07 - accuracy: 1.0000 - val_loss: 2.2780 - val_accuracy: 0.8615
# Epoch 69/100
# 54/54 [==============================] - 1s 9ms/step - loss: 8.4045e-07 - accuracy: 1.0000 - val_loss: 2.2876 - val_accuracy: 0.8615
# Epoch 70/100
# 54/54 [==============================] - 0s 9ms/step - loss: 8.0030e-07 - accuracy: 1.0000 - val_loss: 2.2983 - val_accuracy: 0.8615
# Epoch 71/100
# 54/54 [==============================] - 0s 9ms/step - loss: 7.6950e-07 - accuracy: 1.0000 - val_loss: 2.3061 - val_accuracy: 0.8615
# Epoch 72/100
# 54/54 [==============================] - 1s 10ms/step - loss: 7.2702e-07 - accuracy: 1.0000 - val_loss: 2.3185 - val_accuracy: 0.8615
# Epoch 73/100
# 54/54 [==============================] - 0s 9ms/step - loss: 7.0455e-07 - accuracy: 1.0000 - val_loss: 2.3309 - val_accuracy: 0.8615
# Epoch 74/100
# 54/54 [==============================] - 1s 9ms/step - loss: 6.7607e-07 - accuracy: 1.0000 - val_loss: 2.3328 - val_accuracy: 0.8615
# Epoch 75/100
# 54/54 [==============================] - 0s 9ms/step - loss: 6.3513e-07 - accuracy: 1.0000 - val_loss: 2.3452 - val_accuracy: 0.8615
# Epoch 76/100
# 54/54 [==============================] - 1s 9ms/step - loss: 6.0906e-07 - accuracy: 1.0000 - val_loss: 2.3555 - val_accuracy: 0.8615
# Epoch 77/100
# 54/54 [==============================] - 0s 9ms/step - loss: 5.8708e-07 - accuracy: 1.0000 - val_loss: 2.3650 - val_accuracy: 0.8615
# Epoch 78/100
# 54/54 [==============================] - 1s 10ms/step - loss: 5.6134e-07 - accuracy: 1.0000 - val_loss: 2.3705 - val_accuracy: 0.8615
# Epoch 79/100
# 54/54 [==============================] - 0s 9ms/step - loss: 5.3853e-07 - accuracy: 1.0000 - val_loss: 2.3783 - val_accuracy: 0.8615
# Epoch 80/100
# 54/54 [==============================] - 1s 9ms/step - loss: 5.1915e-07 - accuracy: 1.0000 - val_loss: 2.3896 - val_accuracy: 0.8615
# Epoch 81/100
# 54/54 [==============================] - 1s 9ms/step - loss: 4.9613e-07 - accuracy: 1.0000 - val_loss: 2.3964 - val_accuracy: 0.8615
# Epoch 82/100
# 54/54 [==============================] - 0s 9ms/step - loss: 4.7774e-07 - accuracy: 1.0000 - val_loss: 2.4018 - val_accuracy: 0.8615
# Epoch 83/100
# 54/54 [==============================] - 0s 9ms/step - loss: 4.5887e-07 - accuracy: 1.0000 - val_loss: 2.4091 - val_accuracy: 0.8615
# Epoch 84/100
# 54/54 [==============================] - 0s 9ms/step - loss: 4.3836e-07 - accuracy: 1.0000 - val_loss: 2.4186 - val_accuracy: 0.8615
# Epoch 85/100
# 54/54 [==============================] - 0s 9ms/step - loss: 4.2188e-07 - accuracy: 1.0000 - val_loss: 2.4287 - val_accuracy: 0.8615
# Epoch 86/100
# 54/54 [==============================] - 0s 9ms/step - loss: 4.0423e-07 - accuracy: 1.0000 - val_loss: 2.4364 - val_accuracy: 0.8615
# Epoch 87/100
# 54/54 [==============================] - 1s 9ms/step - loss: 3.9154e-07 - accuracy: 1.0000 - val_loss: 2.4440 - val_accuracy: 0.8615
# Epoch 88/100
# 54/54 [==============================] - 0s 9ms/step - loss: 3.7214e-07 - accuracy: 1.0000 - val_loss: 2.4539 - val_accuracy: 0.8615
# Epoch 89/100
# 54/54 [==============================] - 1s 9ms/step - loss: 3.5767e-07 - accuracy: 1.0000 - val_loss: 2.4612 - val_accuracy: 0.8615
# Epoch 90/100
# 54/54 [==============================] - 1s 10ms/step - loss: 3.4528e-07 - accuracy: 1.0000 - val_loss: 2.4678 - val_accuracy: 0.8615
# Epoch 91/100
# 54/54 [==============================] - 0s 9ms/step - loss: 3.3237e-07 - accuracy: 1.0000 - val_loss: 2.4812 - val_accuracy: 0.8615
# Epoch 92/100
# 54/54 [==============================] - 1s 10ms/step - loss: 3.1830e-07 - accuracy: 1.0000 - val_loss: 2.4837 - val_accuracy: 0.8615
# Epoch 93/100
# 54/54 [==============================] - 1s 9ms/step - loss: 3.0751e-07 - accuracy: 1.0000 - val_loss: 2.4947 - val_accuracy: 0.8615
# Epoch 94/100
# 54/54 [==============================] - 0s 9ms/step - loss: 2.9348e-07 - accuracy: 1.0000 - val_loss: 2.4996 - val_accuracy: 0.8615
# Epoch 95/100
# 54/54 [==============================] - 1s 10ms/step - loss: 2.8279e-07 - accuracy: 1.0000 - val_loss: 2.5067 - val_accuracy: 0.8615
# Epoch 96/100
# 54/54 [==============================] - 0s 9ms/step - loss: 2.7227e-07 - accuracy: 1.0000 - val_loss: 2.5162 - val_accuracy: 0.8615
# Epoch 97/100
# 54/54 [==============================] - 1s 10ms/step - loss: 2.6200e-07 - accuracy: 1.0000 - val_loss: 2.5257 - val_accuracy: 0.8615
# Epoch 98/100
# 54/54 [==============================] - 1s 9ms/step - loss: 2.5354e-07 - accuracy: 1.0000 - val_loss: 2.5332 - val_accuracy: 0.8615
# Epoch 99/100
# 54/54 [==============================] - 1s 9ms/step - loss: 2.4557e-07 - accuracy: 1.0000 - val_loss: 2.5370 - val_accuracy: 0.8615
# Epoch 100/100
# 54/54 [==============================] - 0s 9ms/step - loss: 2.3387e-07 - accuracy: 1.0000 - val_loss: 2.5459 - val_accuracy: 0.8615

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.show()

# %%
img_test = cv2.imread('welding_line/welding_line (10).jpg')
img_test = cv2.resize(img_test, (56, 56))
img_test = [img_test]
img_test = np.array(img_test, dtype = 'float')
img_test /= 255
model.predict(img_test)
# Out:
# array([[1.000000e+00, 1.799932e-16]], dtype=float32)
