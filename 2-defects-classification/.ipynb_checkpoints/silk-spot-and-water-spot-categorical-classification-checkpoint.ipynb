# %% [markdown]
# crease: 52
# crescent_gap: 226
# inclusion: 216
# oil_spot: 204
# punching_hole: 219
# rolled_pit: 31
# silk_spot: 650
# waist_folding: 146
# water_spot: 289
# welding_line: 273

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Flatten
from keras.utils import np_utils
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
X = []
y = []
X_train = []
y_train = []
X_test = []
y_test = []
w = 56
l = 56

# %%
cd "C:\\Users\\Toqa Alaa\\PBL2\\gc10det"
# Out:
# C:\Users\Toqa Alaa\PBL2\gc10det

# %%
fig = plt.figure(figsize=(10, 10))
for i in range(1, 11):
    img = cv2.imread(fr'crease/crease ({i}).jpg')
    img = cv2.resize(img, (56, 56))
    fig.add_subplot(2, 5, i)
    plt.imshow(img, aspect = 'auto')
    plt.grid(False)
plt.show()

print(img.shape)
# Out:
# (56, 56, 3)

# %%
for i in range(1, 651):
    img = cv2.imread(fr'silk_spot/silk_spot ({i}).jpg')
    img = cv2.resize(img, (l, w))
    X.append(img)
    y.append(0)

for i in range(1, 290):
    img = cv2.imread(fr'water_spot/water_spot ({i}).jpg')
    img = cv2.resize(img, (l, w))
    X.append(img)
    y.append(1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
X_train = np.array(X_train, dtype = 'float')
y_train = np.array(y_train, dtype = 'float').astype('float32').reshape((-1,1))
X_test = np.array(X_test, dtype = 'float')
y_test = np.array(y_test, dtype = 'float').astype('float32').reshape((-1,1))

# %%
n_classes = 2

X_train /= 255
X_test /= 255
y_train = np_utils.to_categorical(y_train, n_classes)
y_test = np_utils.to_categorical(y_test, n_classes)

# %%
model = Sequential()
model.add(Conv2D(56, kernel_size=(2,2), strides=(1,1), padding='valid', activation='relu', input_shape=(w,l,3)))
model.add(MaxPool2D(pool_size=(1,1)))

model.add(Flatten())

model.add(Dense(112, activation='relu'))
model.add(Dense(56, activation='relu'))
model.add(Dense(28, activation='relu'))

model.add(Dense(2, activation='sigmoid'))

model.compile(loss = 'binary_crossentropy', metrics = ['accuracy'], optimizer = 'adam')

# %%
N = 100

H = model.fit(X_train, y_train, batch_size = 15, epochs = N, validation_data = (X_test, y_test))
model.save("model.h5")
# Out:
# Epoch 1/100
# 51/51 [==============================] - 13s 17ms/step - loss: 0.7358 - accuracy: 0.6937 - val_loss: 0.4875 - val_accuracy: 0.7234
# Epoch 2/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.4160 - accuracy: 0.8109 - val_loss: 0.3673 - val_accuracy: 0.8351
# Epoch 3/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.3547 - accuracy: 0.8296 - val_loss: 0.3740 - val_accuracy: 0.8404
# Epoch 4/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.3365 - accuracy: 0.8442 - val_loss: 0.3552 - val_accuracy: 0.8617
# Epoch 5/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.3237 - accuracy: 0.8495 - val_loss: 0.3592 - val_accuracy: 0.8511
# Epoch 6/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2903 - accuracy: 0.8549 - val_loss: 0.2869 - val_accuracy: 0.8617
# Epoch 7/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.2656 - accuracy: 0.8748 - val_loss: 0.2863 - val_accuracy: 0.8191
# Epoch 8/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2561 - accuracy: 0.8682 - val_loss: 0.2569 - val_accuracy: 0.9043
# Epoch 9/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2448 - accuracy: 0.8855 - val_loss: 0.2629 - val_accuracy: 0.8830
# Epoch 10/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2365 - accuracy: 0.8868 - val_loss: 0.4566 - val_accuracy: 0.8511
# Epoch 11/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2586 - accuracy: 0.8828 - val_loss: 0.2694 - val_accuracy: 0.8457
# Epoch 12/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2450 - accuracy: 0.8868 - val_loss: 0.2534 - val_accuracy: 0.8936
# Epoch 13/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2297 - accuracy: 0.8895 - val_loss: 0.2566 - val_accuracy: 0.8830
# Epoch 14/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2144 - accuracy: 0.9041 - val_loss: 0.2321 - val_accuracy: 0.8989
# Epoch 15/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.1921 - accuracy: 0.9174 - val_loss: 0.2569 - val_accuracy: 0.8883
# Epoch 16/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2051 - accuracy: 0.9134 - val_loss: 0.2482 - val_accuracy: 0.8883
# Epoch 17/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.1764 - accuracy: 0.9241 - val_loss: 0.2652 - val_accuracy: 0.8936
# Epoch 18/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.1338 - accuracy: 0.9507 - val_loss: 0.2862 - val_accuracy: 0.8883
# Epoch 19/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.1333 - accuracy: 0.9561 - val_loss: 0.3068 - val_accuracy: 0.8670
# Epoch 20/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1250 - accuracy: 0.9561 - val_loss: 0.5269 - val_accuracy: 0.8457
# Epoch 21/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.1215 - accuracy: 0.9561 - val_loss: 0.2700 - val_accuracy: 0.9149
# Epoch 22/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.1768 - accuracy: 0.9228 - val_loss: 0.2606 - val_accuracy: 0.9043
# Epoch 23/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.1687 - accuracy: 0.9201 - val_loss: 0.2593 - val_accuracy: 0.8777
# Epoch 24/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2637 - accuracy: 0.8802 - val_loss: 0.2678 - val_accuracy: 0.8723
# Epoch 25/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2520 - accuracy: 0.8895 - val_loss: 0.2603 - val_accuracy: 0.8777
# Epoch 26/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.1792 - accuracy: 0.9228 - val_loss: 0.3025 - val_accuracy: 0.8511
# Epoch 27/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.1358 - accuracy: 0.9494 - val_loss: 0.3112 - val_accuracy: 0.8138
# Epoch 28/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2264 - accuracy: 0.8948 - val_loss: 0.2602 - val_accuracy: 0.8830
# Epoch 29/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2497 - accuracy: 0.8802 - val_loss: 0.2706 - val_accuracy: 0.8830
# Epoch 30/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2418 - accuracy: 0.8815 - val_loss: 0.2706 - val_accuracy: 0.8830
# Epoch 31/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2495 - accuracy: 0.8868 - val_loss: 0.2729 - val_accuracy: 0.8723
# Epoch 32/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2345 - accuracy: 0.8868 - val_loss: 0.2656 - val_accuracy: 0.8777
# Epoch 33/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2318 - accuracy: 0.8855 - val_loss: 0.3253 - val_accuracy: 0.8245
# Epoch 34/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2355 - accuracy: 0.8868 - val_loss: 0.2636 - val_accuracy: 0.8883
# Epoch 35/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2306 - accuracy: 0.8881 - val_loss: 0.4082 - val_accuracy: 0.7447
# Epoch 36/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2639 - accuracy: 0.8722 - val_loss: 0.2738 - val_accuracy: 0.8777
# Epoch 37/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2360 - accuracy: 0.8855 - val_loss: 0.2781 - val_accuracy: 0.8777
# Epoch 38/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2311 - accuracy: 0.8855 - val_loss: 0.2986 - val_accuracy: 0.8723
# Epoch 39/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2134 - accuracy: 0.8948 - val_loss: 0.4472 - val_accuracy: 0.8617
# Epoch 40/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2322 - accuracy: 0.8881 - val_loss: 0.2956 - val_accuracy: 0.8830
# Epoch 41/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2236 - accuracy: 0.8881 - val_loss: 0.2963 - val_accuracy: 0.8777
# Epoch 42/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2217 - accuracy: 0.8881 - val_loss: 0.2942 - val_accuracy: 0.8830
# Epoch 43/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2175 - accuracy: 0.8908 - val_loss: 0.2991 - val_accuracy: 0.8830
# Epoch 44/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2186 - accuracy: 0.8935 - val_loss: 0.2941 - val_accuracy: 0.8830
# Epoch 45/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.1679 - accuracy: 0.9401 - val_loss: 0.2719 - val_accuracy: 0.8830
# Epoch 46/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2402 - accuracy: 0.8828 - val_loss: 0.2901 - val_accuracy: 0.8830
# Epoch 47/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2343 - accuracy: 0.8881 - val_loss: 0.2803 - val_accuracy: 0.8777
# Epoch 48/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.1768 - accuracy: 0.9254 - val_loss: 0.2948 - val_accuracy: 0.9149
# Epoch 49/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.1236 - accuracy: 0.9574 - val_loss: 0.3624 - val_accuracy: 0.8777
# Epoch 50/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2740 - accuracy: 0.8842 - val_loss: 0.3056 - val_accuracy: 0.8777
# Epoch 51/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.1557 - accuracy: 0.9268 - val_loss: 0.3492 - val_accuracy: 0.8936
# Epoch 52/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.1171 - accuracy: 0.9521 - val_loss: 0.3154 - val_accuracy: 0.9043
# Epoch 53/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.1716 - accuracy: 0.9201 - val_loss: 0.4981 - val_accuracy: 0.8457
# Epoch 54/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0694 - accuracy: 0.9787 - val_loss: 0.4115 - val_accuracy: 0.9149
# Epoch 55/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0532 - accuracy: 0.9893 - val_loss: 0.4615 - val_accuracy: 0.8670
# Epoch 56/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0346 - accuracy: 0.9920 - val_loss: 0.5171 - val_accuracy: 0.8830
# Epoch 57/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0288 - accuracy: 0.9920 - val_loss: 0.4499 - val_accuracy: 0.8936
# Epoch 58/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0153 - accuracy: 0.9987 - val_loss: 0.5438 - val_accuracy: 0.8989
# Epoch 59/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0081 - accuracy: 0.9987 - val_loss: 0.6019 - val_accuracy: 0.9096
# Epoch 60/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.6198 - val_accuracy: 0.9096
# Epoch 61/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.6282 - val_accuracy: 0.9043
# Epoch 62/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.6285 - val_accuracy: 0.9043
# Epoch 63/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.6817 - val_accuracy: 0.9043
# Epoch 64/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.6967 - val_accuracy: 0.9043
# Epoch 65/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.7032 - val_accuracy: 0.9043
# Epoch 66/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.7140 - val_accuracy: 0.9043
# Epoch 67/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.7135 - val_accuracy: 0.8936
# Epoch 68/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.7376 - val_accuracy: 0.9043
# Epoch 69/100
# 51/51 [==============================] - 0s 9ms/step - loss: 8.5979e-04 - accuracy: 1.0000 - val_loss: 0.7401 - val_accuracy: 0.8936
# Epoch 70/100
# 51/51 [==============================] - 0s 9ms/step - loss: 7.4081e-04 - accuracy: 1.0000 - val_loss: 0.7516 - val_accuracy: 0.8936
# Epoch 71/100
# 51/51 [==============================] - 0s 9ms/step - loss: 6.8571e-04 - accuracy: 1.0000 - val_loss: 0.7581 - val_accuracy: 0.8936
# Epoch 72/100
# 51/51 [==============================] - 0s 8ms/step - loss: 5.8797e-04 - accuracy: 1.0000 - val_loss: 0.7759 - val_accuracy: 0.8989
# Epoch 73/100
# 51/51 [==============================] - 0s 9ms/step - loss: 5.2214e-04 - accuracy: 1.0000 - val_loss: 0.7780 - val_accuracy: 0.8936
# Epoch 74/100
# 51/51 [==============================] - 0s 8ms/step - loss: 5.0241e-04 - accuracy: 1.0000 - val_loss: 0.7893 - val_accuracy: 0.8936
# Epoch 75/100
# 51/51 [==============================] - 0s 8ms/step - loss: 4.9803e-04 - accuracy: 1.0000 - val_loss: 0.7892 - val_accuracy: 0.8883
# Epoch 76/100
# 51/51 [==============================] - 0s 9ms/step - loss: 4.1645e-04 - accuracy: 1.0000 - val_loss: 0.8066 - val_accuracy: 0.8936
# Epoch 77/100
# 51/51 [==============================] - 0s 8ms/step - loss: 3.7691e-04 - accuracy: 1.0000 - val_loss: 0.8132 - val_accuracy: 0.8936
# Epoch 78/100
# 51/51 [==============================] - 0s 9ms/step - loss: 3.2459e-04 - accuracy: 1.0000 - val_loss: 0.8153 - val_accuracy: 0.8936
# Epoch 79/100
# 51/51 [==============================] - 0s 9ms/step - loss: 3.0112e-04 - accuracy: 1.0000 - val_loss: 0.8345 - val_accuracy: 0.8989
# Epoch 80/100
# 51/51 [==============================] - 0s 9ms/step - loss: 2.8973e-04 - accuracy: 1.0000 - val_loss: 0.8326 - val_accuracy: 0.8989
# Epoch 81/100
# 51/51 [==============================] - 0s 9ms/step - loss: 2.6643e-04 - accuracy: 1.0000 - val_loss: 0.8342 - val_accuracy: 0.8936
# Epoch 82/100
# 51/51 [==============================] - 0s 8ms/step - loss: 2.5079e-04 - accuracy: 1.0000 - val_loss: 0.8421 - val_accuracy: 0.8936
# Epoch 83/100
# 51/51 [==============================] - 0s 9ms/step - loss: 2.3307e-04 - accuracy: 1.0000 - val_loss: 0.8517 - val_accuracy: 0.8989
# Epoch 84/100
# 51/51 [==============================] - 0s 8ms/step - loss: 2.1402e-04 - accuracy: 1.0000 - val_loss: 0.8461 - val_accuracy: 0.8883
# Epoch 85/100
# 51/51 [==============================] - 0s 9ms/step - loss: 2.1885e-04 - accuracy: 1.0000 - val_loss: 0.8509 - val_accuracy: 0.8936
# Epoch 86/100
# 51/51 [==============================] - 0s 9ms/step - loss: 1.8168e-04 - accuracy: 1.0000 - val_loss: 0.8643 - val_accuracy: 0.8989
# Epoch 87/100
# 51/51 [==============================] - 0s 9ms/step - loss: 1.7377e-04 - accuracy: 1.0000 - val_loss: 0.8712 - val_accuracy: 0.8989
# Epoch 88/100
# 51/51 [==============================] - 0s 8ms/step - loss: 1.6328e-04 - accuracy: 1.0000 - val_loss: 0.8772 - val_accuracy: 0.8989
# Epoch 89/100
# 51/51 [==============================] - 0s 8ms/step - loss: 1.6251e-04 - accuracy: 1.0000 - val_loss: 0.8690 - val_accuracy: 0.8936
# Epoch 90/100
# 51/51 [==============================] - 0s 9ms/step - loss: 1.5064e-04 - accuracy: 1.0000 - val_loss: 0.8750 - val_accuracy: 0.8936
# Epoch 91/100
# 51/51 [==============================] - 0s 8ms/step - loss: 1.3279e-04 - accuracy: 1.0000 - val_loss: 0.8731 - val_accuracy: 0.8883
# Epoch 92/100
# 51/51 [==============================] - 0s 9ms/step - loss: 1.3585e-04 - accuracy: 1.0000 - val_loss: 0.8840 - val_accuracy: 0.8936
# Epoch 93/100
# 51/51 [==============================] - 0s 8ms/step - loss: 1.2368e-04 - accuracy: 1.0000 - val_loss: 0.8907 - val_accuracy: 0.8936
# Epoch 94/100
# 51/51 [==============================] - 0s 9ms/step - loss: 1.1389e-04 - accuracy: 1.0000 - val_loss: 0.8986 - val_accuracy: 0.8989
# Epoch 95/100
# 51/51 [==============================] - 0s 8ms/step - loss: 1.2989e-04 - accuracy: 1.0000 - val_loss: 0.8992 - val_accuracy: 0.8989
# Epoch 96/100
# 51/51 [==============================] - 0s 8ms/step - loss: 9.9007e-05 - accuracy: 1.0000 - val_loss: 0.8946 - val_accuracy: 0.8936
# Epoch 97/100
# 51/51 [==============================] - 0s 9ms/step - loss: 9.5379e-05 - accuracy: 1.0000 - val_loss: 0.8982 - val_accuracy: 0.8936
# Epoch 98/100
# 51/51 [==============================] - 0s 9ms/step - loss: 9.6636e-05 - accuracy: 1.0000 - val_loss: 0.9060 - val_accuracy: 0.8936
# Epoch 99/100
# 51/51 [==============================] - 0s 8ms/step - loss: 8.6618e-05 - accuracy: 1.0000 - val_loss: 0.9085 - val_accuracy: 0.8936
# Epoch 100/100
# 51/51 [==============================] - 0s 8ms/step - loss: 8.1223e-05 - accuracy: 1.0000 - val_loss: 0.9110 - val_accuracy: 0.8936

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.show()

# %%
img_test = cv2.imread(r'water_spot/water_spot (50).jpg')
img_test = cv2.resize(img_test, (l, w))
img_test = [img_test]
img_test = np.array(img_test, dtype = 'float')
img_test /= 255
model.predict(img_test)
# Out:
# array([[1.0991301e-18, 1.0000000e+00]], dtype=float32)

# %%
DataSet_length= len(X)
incorrect_predictions= 0

for i in range(DataSet_length-1):
    random_image= X[i]
    real_val= y[i]
    random_img= X[i]
    random_img=[random_img]
    random_img = np.array(random_img, dtype = 'float')
    random_img/=255
    prediction = model.predict(random_img)
    yhat = np.argmax(prediction)
    if yhat!= real_val:
        incorrect_predictions+=1
        
print(incorrect_predictions)
# Out:
# 20

# %%
print(DataSet_length)
# Out:
# 939
