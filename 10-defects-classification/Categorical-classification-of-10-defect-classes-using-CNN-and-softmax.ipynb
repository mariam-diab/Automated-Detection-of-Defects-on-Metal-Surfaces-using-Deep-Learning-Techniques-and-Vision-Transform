# %% [markdown]
# crease: 216
# crescent_gap: 226
# inclusion: 492
# oil_spot: 204
# punching_hole: 219
# rolled_pit: 426
# silk_spot: 650
# waist_folding: 146
# water_spot: 289
# welding_line: 273

# %%
import os
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout
from keras.utils import np_utils
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
X = []
y = []
X_train = []
y_train = []
X_test = []
y_test = []
w = 56
l = 56

# %%
cd "C:\\Users\\Toqa Alaa\\PBL2\\gc10det"
# Out:
# C:\Users\Toqa Alaa\PBL2\gc10det

# %%
#Displaying sample data for the 4 classes
path ='waist_folding'
for img in os.listdir(path):  # iterate over each image per dogs and cats
    img_array1 = cv2.imread(os.path.join(path,img))  # convert to array
    break

path ='punching_hole'
for img in os.listdir(path):  # iterate over each image per dogs and cats
    img_array2 = cv2.imread(os.path.join(path,img))  # convert to array
    break
    
    
path ='water_spot'
for img in os.listdir(path):  # iterate over each image per dogs and cats
    img_array3 = cv2.imread(os.path.join(path,img))  # convert to array
    break
    
    
path ='welding_line'
for img in os.listdir(path):  # iterate over each image per dogs and cats
    img_array4 = cv2.imread(os.path.join(path,img))  # convert to array
    break
    
path ='crease'
for img in os.listdir(path):  # iterate over each image per dogs and cats
    img_array5 = cv2.imread(os.path.join(path,img))  # convert to array
    break
    
path ='crescent_gap'
for img in os.listdir(path):  # iterate over each image per dogs and cats
    img_array6 = cv2.imread(os.path.join(path,img))  # convert to array
    break

path ='inclusion'
for img in os.listdir(path):  # iterate over each image per dogs and cats
    img_array7 = cv2.imread(os.path.join(path,img))  # convert to array
    break
    
    
path ='oil_spot'
for img in os.listdir(path):  # iterate over each image per dogs and cats
    img_array8 = cv2.imread(os.path.join(path,img))  # convert to array
    break
    
    
path ='rolled_pit'
for img in os.listdir(path):  # iterate over each image per dogs and cats
    img_array9 = cv2.imread(os.path.join(path,img))  # convert to array
    break
    
path ='silk_spot'
for img in os.listdir(path):  # iterate over each image per dogs and cats
    img_array10 = cv2.imread(os.path.join(path,img))  # convert to array
    break
    
fig = plt.figure(figsize=(30, 6))
ax1 = fig.add_subplot(2, 5, 1)
ax1.imshow(img_array1, cmap='gray')
fig.suptitle("Sample images for 10 classes")
ax1.set_title("Waist folding")
ax2 = fig.add_subplot(2, 5, 2)
ax2.imshow(img_array2, cmap='gray')
ax2.set_title("Punshing Hole")
ax3 = fig.add_subplot(2, 5, 3)
ax3.imshow(img_array3, cmap='gray')
ax3.set_title("Water spot")
ax4 = fig.add_subplot(2, 5, 4)
ax4.imshow(img_array4, cmap='gray')
ax4.set_title("Welding line")
ax5 = fig.add_subplot(2, 5, 5)
ax5.imshow(img_array5, cmap='gray')
ax5.set_title("Crease")
ax6 = fig.add_subplot(2, 5, 6)
ax6.imshow(img_array6, cmap='gray')
ax6.set_title("Crescent Gap", y=-0.3)
ax7 = fig.add_subplot(2, 5, 7)
ax7.imshow(img_array7, cmap='gray')
ax7.set_title("Inclusion", y=-0.3)
ax8 = fig.add_subplot(2, 5, 8)
ax8.imshow(img_array8, cmap='gray')
ax8.set_title("Oil Spot", y=-0.3)
ax9 = fig.add_subplot(2, 5, 9)
ax9.imshow(img_array9, cmap='gray')
ax9.set_title("Rolled Pit", y=-0.3)
ax10 = fig.add_subplot(2, 5, 10)
ax10.imshow(img_array10, cmap='gray')
ax10.set_title("Silk Spot", y=-0.3)
# Out:
# Text(0.5, -0.3, 'Silk Spot')

# %%
for i in range(1, 53):
    img = cv2.imread(fr'crease/crease ({i}).jpg')
    img = cv2.resize(img, (l, w))
    X.append(img)
    y.append(0)

for i in range(1, 227):
    img = cv2.imread(fr'crescent_gap/crescent_gap ({i}).jpg')
    img = cv2.resize(img, (l, w))
    X.append(img)
    y.append(1)
    
for i in range(1, 493):
    img = cv2.imread(fr'inclusion/inclusion ({i}).jpg')
    img = cv2.resize(img, (l, w))
    X.append(img)
    y.append(2)

for i in range(1, 205):
    img = cv2.imread(fr'oil_spot/oil_spot ({i}).jpg')
    img = cv2.resize(img, (l, w))
    X.append(img)
    y.append(3)

for i in range(1, 220):
    img = cv2.imread(fr'punching_hole/punching_hole ({i}).jpg')
    img = cv2.resize(img, (l, w))
    X.append(img)
    y.append(4)

for i in range(1, 31):
    img = cv2.imread(fr'rolled_pit/rolled_pit ({i}).jpg')
    img = cv2.resize(img, (l, w))
    X.append(img)
    y.append(5)
    
for i in range(1, 651):
    img = cv2.imread(fr'silk_spot/silk_spot ({i}).jpg')
    img = cv2.resize(img, (l, w))
    X.append(img)
    y.append(6)

for i in range(1, 147):
    img = cv2.imread(fr'waist_folding/waist_folding ({i}).jpg')
    img = cv2.resize(img, (l, w))
    X.append(img)
    y.append(7)
    
for i in range(1, 290):
    img = cv2.imread(fr'water_spot/water_spot ({i}).jpg')
    img = cv2.resize(img, (l, w))
    X.append(img)
    y.append(8)

for i in range(1, 274):
    img = cv2.imread(fr'welding_line/welding_line ({i}).jpg')
    img = cv2.resize(img, (l, w))
    X.append(img)
    y.append(9)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %%
X_train = np.array(X_train, dtype = 'float')
y_train = np.array(y_train, dtype = 'float').astype('float32').reshape((-1,1))
X_test = np.array(X_test, dtype = 'float')
y_test = np.array(y_test, dtype = 'float').astype('float32').reshape((-1,1))

# %%
n_classes = 10

X_train /= 255
X_test /= 255
#y_train = np_utils.to_categorical(y_train, n_classes)
#y_test = np_utils.to_categorical(y_test, n_classes)

# %%
model = Sequential()
model.add(Conv2D(56, kernel_size=(2,2), strides=(1,1), padding='valid', activation='relu', input_shape=(w,l,3)))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Flatten())

model.add(Dense(112, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(224, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(112, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(56, activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(10, activation='linear'))

model.compile(loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.001), metrics = ['accuracy'])

# %%
N = 100

H = model.fit(X_train, y_train, batch_size = 10, epochs = N, validation_data = (X_test, y_test))
model.save("model2.h5")
# Out:
# Epoch 1/100
# 270/270 [==============================] - 9s 8ms/step - loss: 2.1440 - accuracy: 0.2585 - val_loss: 1.9300 - val_accuracy: 0.3359
# Epoch 2/100
# 270/270 [==============================] - 2s 7ms/step - loss: 1.9309 - accuracy: 0.3519 - val_loss: 1.7550 - val_accuracy: 0.4197
# Epoch 3/100
# 270/270 [==============================] - 2s 7ms/step - loss: 1.7927 - accuracy: 0.4030 - val_loss: 1.6397 - val_accuracy: 0.4404
# Epoch 4/100
# 270/270 [==============================] - 2s 7ms/step - loss: 1.7237 - accuracy: 0.4396 - val_loss: 1.6346 - val_accuracy: 0.4922
# Epoch 5/100
# 270/270 [==============================] - 2s 7ms/step - loss: 1.6653 - accuracy: 0.4519 - val_loss: 1.5477 - val_accuracy: 0.5138
# Epoch 6/100
# 270/270 [==============================] - 2s 7ms/step - loss: 1.6059 - accuracy: 0.4589 - val_loss: 1.4609 - val_accuracy: 0.5630
# Epoch 7/100
# ...

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.show()

# %%
# DataSet_length= len(X)
# incorrect_predictions= 0

# for i in range(DataSet_length-1):
#     random_image= X[i]
#     real_val= y[i]
#     random_img= X[i]
#     random_img=[random_img]
#     random_img = np.array(random_img, dtype = 'float')
#     random_img/=255
#     prediction = model.predict(random_img)
#     yhat = np.argmax(prediction)
#     if yhat!= real_val:
#         incorrect_predictions+=1
        
# print(incorrect_predictions)
# print(DataSet_length)
